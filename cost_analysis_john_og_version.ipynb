# %% [markdown]
# # Model Cost Calculator
# #
# # This notebook imports functions from the codebase and is NOT fully standalone
# # Requires: cost.py, data.py, prices.py, hardware.py, energy.py, parameters.py, inflation.py
# # Also requires data files: All ML Systems - full view.csv, Hardware prices.csv, Chip dataset-Grid view.csv, PCU518210518210.csv, frontier_systems_by_*.json
# #
# # Simplified cost estimation for frontier ML models with configurable parameters and real pricing data."

# %%
# Configuration
compute_threshold_method = 'top_n'  # 'top_n', 'window_percentile', 'backward_window_percentile', 'residual_from_trend'
compute_threshold = 10  # e.g. 10 for top 10 models, 75 for top 25%

# Imputation configuration
enable_imputation = True  # Set to False to disable imputation
imputation_method = 'most_common'  # 'knn', 'most_common', 'none'
knn_neighbors = 5  # Number of neighbors for KNN imputation (if using KNN)

# Output file
output_file = 'model_costs.csv'

# %%
# Install required packages
import subprocess
import sys

def install_package(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Install core dependencies
try:
    import scipy
except ImportError:
    install_package("scipy")
    
try:
    import sklearn
except ImportError:
    install_package("scikit-learn")

import json
import numpy as np
import pandas as pd

# Import core modules - use full module imports to avoid circular dependency issues
import cost
import data
import prices
import inflation
import energy
import hardware
import parameters
import imputation  # Import imputation module for data quality checks

# %%
# Load data using existing pipeline
frontier_df, hardware_df, price_df = data.load_data_for_cost_estimation(
    compute_threshold_method=compute_threshold_method, 
    compute_threshold=compute_threshold
)

print(f"Loaded {len(frontier_df)} frontier models for cost estimation")

# Data quality report before imputation
print("\nData Quality Report (Before Imputation):")
print(f"Models with known Training hardware: {frontier_df['Training hardware'].notna().sum()}/{len(frontier_df)}")
print(f"Models with known Hardware quantity: {frontier_df['Hardware quantity'].notna().sum()}/{len(frontier_df)}")
print(f"Models with known Hardware utilization: {frontier_df['Hardware utilization'].notna().sum()}/{len(frontier_df)}")
print(f"Models with known Training time (hours): {frontier_df['Training time (hours)'].notna().sum()}/{len(frontier_df)}")
print(f"Models with known Training compute (FLOP): {frontier_df['Training compute (FLOP)'].notna().sum()}/{len(frontier_df)}")

# Apply imputation if enabled
if enable_imputation and imputation_method != 'none':
    print(f"\nApplying {imputation_method} imputation...")
    
    if imputation_method == 'knn':
        # Apply KNN imputation - uses the established pipeline from imputation.py
        frontier_df = imputation.knn_impute_pcd(
            frontier_df.copy(), 
            num_neighbors_general=knn_neighbors,
            num_neighbors_training_hardware=knn_neighbors
        )
        print(f"Applied KNN imputation with {knn_neighbors} neighbors")
        
    elif imputation_method == 'most_common':
        # Apply most common value imputation for training hardware
        frontier_df = imputation.most_common_impute_training_hardware(frontier_df.copy())
        print("Applied most common value imputation for training hardware")
    
    # Data quality report after imputation
    print("\nData Quality Report (After Imputation):")
    print(f"Models with known Training hardware: {frontier_df['Training hardware'].notna().sum()}/{len(frontier_df)}")
    print(f"Models with known Hardware quantity: {frontier_df['Hardware quantity'].notna().sum()}/{len(frontier_df)}")
    print(f"Models with known Hardware utilization: {frontier_df['Hardware utilization'].notna().sum()}/{len(frontier_df)}")
    print(f"Models with known Training time (hours): {frontier_df['Training time (hours)'].notna().sum()}/{len(frontier_df)}")
    print(f"Models with known Training compute (FLOP): {frontier_df['Training compute (FLOP)'].notna().sum()}/{len(frontier_df)}")
else:
    print("\nSkipping imputation (disabled in configuration)")

# Summary of missing data
missing_data_summary = {
    'Total models': len(frontier_df),
    'Missing training hardware': frontier_df['Training hardware'].isna().sum(),
    'Missing hardware quantity': frontier_df['Hardware quantity'].isna().sum(),
    'Missing hardware utilization': frontier_df['Hardware utilization'].isna().sum(),
    'Missing training time': frontier_df['Training time (hours)'].isna().sum(),
    'Missing training compute': frontier_df['Training compute (FLOP)'].isna().sum()
}

print(f"\nMissing Data Summary:")
for key, value in missing_data_summary.items():
    print(f"{key}: {value}")
# Out:
# Loaded 89 frontier models for cost estimation
#
# Data Quality Report (Before Imputation):
# Models with known Training hardware: 66/89
# Models with known Hardware quantity: 49/89
# Models with known Hardware utilization: 23/89
# Models with known Training time (hours): 44/89
# Models with known Training compute (FLOP): 89/89
#
# Applying most_common imputation...
# Applied most common value imputation for training hardware
#
# Data Quality Report (After Imputation):
# Models with known Training hardware: 89/89
# Models with known Hardware quantity: 49/89
# Models with known Hardware utilization: 23/89
# Models with known Training time (hours): 44/89
# Models with known Training compute (FLOP): 89/89
#
# Missing Data Summary:
# Total models: 89
# Missing training hardware: 0
# Missing hardware quantity: 40
# Missing hardware utilization: 66
# Missing training time: 45
# Missing training compute: 0

# %%
# Removed: Manual cost calculation functions
# Now using the integrated cost estimation pipeline with proper imputation support
# The cost.py functions handle all the complexity of cost estimation and imputation

# %%
# Run all three cost estimation methods
print("Running all cost estimation methods...")

# Determine imputation function based on configuration
impute_pcd_fn = None
impute_kwargs = {}

if enable_imputation and imputation_method != 'none':
    if imputation_method == 'knn':
        impute_pcd_fn = imputation.knn_impute_pcd
        impute_kwargs = {
            'num_neighbors_general': knn_neighbors,
            'num_neighbors_training_hardware': knn_neighbors
        }
    elif imputation_method == 'most_common':
        impute_pcd_fn = imputation.most_common_impute_training_hardware
        impute_kwargs = {}

# Create separate DataFrames for each method to avoid interference
methods = ['cloud', 'hardware-acquisition', 'hardware-capex-energy']
method_results = {}

for method in methods:
    print(f"\n{'='*50}")
    print(f"Calculating costs using {method} method...")
    print(f"{'='*50}")
    
    # Create fresh copy of data for each method
    method_df = frontier_df.copy()
    
    try:
        # Calculate costs using the appropriate method with imputation support
        if method == 'cloud':
            method_df = cost.estimate_cloud_costs(
                method_df, hardware_df, price_df,
                impute_pcd_fn=impute_pcd_fn, **impute_kwargs
            )
        elif method == 'hardware-acquisition':
            method_df = cost.estimate_hardware_acquisition_cost(
                method_df, hardware_df, price_df,
                impute_pcd_fn=impute_pcd_fn, **impute_kwargs
            )
        elif method == 'hardware-capex-energy':
            method_df = cost.estimate_hardware_capex_energy(
                method_df, hardware_df, price_df,
                impute_pcd_fn=impute_pcd_fn, **impute_kwargs
            )
        
        # Apply inflation adjustment using existing function
        print("Applying inflation adjustment to 2024 dollars...")
        method_df = inflation.adjust_column_for_inflation(method_df, 'Cost', 'data/PCU518210518210.csv', '2024-12-01')
        
        # Store results with inflation-adjusted costs
        cost_column = 'Cost (inflation-adjusted)'
        successful_estimates = method_df[method_df[cost_column].notna()]
        
        print(f"Successfully calculated costs for {len(successful_estimates)} models")
        print(f"Failed to calculate costs for {len(method_df) - len(successful_estimates)} models")
        
        # Store the results
        method_results[method] = successful_estimates[['Model', cost_column]].copy()
        
    except Exception as e:
        print(f"Error in {method} method: {str(e)}")
        method_results[method] = pd.DataFrame(columns=['Model', 'Cost (inflation-adjusted)'])

# Display summary of results
print(f"\n{'='*60}")
print("SUMMARY OF ALL METHODS")
print(f"{'='*60}")
for method, df in method_results.items():
    print(f"{method}: {len(df)} successful cost estimates")
    if len(df) > 0:
        print(f"  Min: ${df['Cost (inflation-adjusted)'].min():,.0f}")
        print(f"  Max: ${df['Cost (inflation-adjusted)'].max():,.0f}")
        print(f"  Median: ${df['Cost (inflation-adjusted)'].median():,.0f}")
    print()

# Validation: Report on imputation impact for the first method
if enable_imputation and imputation_method != 'none':
    print(f"Imputation Impact Assessment:")
    print(f"Imputation method used: {imputation_method}")
    if imputation_method == 'knn':
        print(f"KNN neighbors: {knn_neighbors}")
    
    # Calculate how many models benefited from imputation by comparing before/after
    original_frontier_df, _, _ = data.load_data_for_cost_estimation(
        compute_threshold_method=compute_threshold_method, 
        compute_threshold=compute_threshold
    )
    
    # Run cost estimation WITHOUT imputation to get baseline (using hardware-capex-energy as reference)
    original_results = cost.estimate_hardware_capex_energy(original_frontier_df, hardware_df, price_df)
    original_results = inflation.adjust_column_for_inflation(original_results, 'Cost', 'data/PCU518210518210.csv', '2024-12-01')
    original_success_count = original_results['Cost (inflation-adjusted)'].notna().sum()
    
    models_with_missing_data = (
        original_frontier_df['Training hardware'].isna() |
        original_frontier_df['Hardware quantity'].isna() |
        original_frontier_df['Training time (hours)'].isna()
    ).sum()
    
    print(f"Models with missing critical data (pre-imputation): {models_with_missing_data}")
    print(f"Models with successful cost estimates WITHOUT imputation: {original_success_count}")
    print(f"Models with successful cost estimates WITH imputation (hardware-capex-energy): {len(method_results['hardware-capex-energy'])}")
    
    # Calculate the actual imputation impact
    imputation_enabled_count = len(method_results['hardware-capex-energy']) - original_success_count
    if imputation_enabled_count > 0:
        print(f"✓ Imputation enabled cost estimation for {imputation_enabled_count} additional models")
    elif imputation_enabled_count == 0:
        print("= Imputation did not enable cost estimation for any additional models")
    else:
        print(f"! Imputation resulted in {-imputation_enabled_count} fewer successful cost estimates")
# Out:
# Running all cost estimation methods...
#
# ==================================================
# Calculating costs using cloud method...
# ==================================================
# ==== System: Llama 4 Behemoth (preview) ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA H100 SXM5 80GB at 2024-11-02 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -135 days +22:30:00
#
# ==== System: GPT-4.5 ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA H100 SXM5 80GB at 2024-09-26 22:30:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -172 days +22:30:00
#
# ==== System: Claude 3.7 Sonnet ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA H100 SXM5 80GB at 2024-09-23 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -175 days +22:30:00
#
# ==== System: Grok-3 ====
# Trying NVIDIA H100 SXM5 80GB at 2024-07-12 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -248 days +00:00:00
#
# ==== System: Doubao-pro ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2024-05-27 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 535 days 22:30:00
#
# ==== System: GLM-4-Plus ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2024-03-28 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 475 days 22:30:00
#
# ==== System: Grok-2 ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA H100 SXM5 80GB at 2024-03-12 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -370 days +22:30:00
#
# ==== System: Mistral Large 2 ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2024-02-21 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 439 days 22:30:00
#
# ==== System: Llama 3.1-405B ====
# Trying NVIDIA H100 SXM5 80GB at 2023-12-26 18:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -447 days +18:00:00
#
# ==== System: Claude 3.5 Sonnet ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2024-01-18 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 405 days 22:30:00
#
# ==== System: Nemotron-4 340B ====
# Trying NVIDIA H100 SXM5 80GB at 2023-11-15 08:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -488 days +08:00:00
#
# ==== System: GPT-4o ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2023-12-11 22:30:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Found price: 1.36 at 2022-01-20 00:00:00
# Difference between acquisition date and price date: 690 days 22:30:00
#
# ==== System: Reka Core ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100,NVIDIA H100 SXM5 80GB at 2023-11-13 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (on-demand)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (on-demand)
# Could not find price
#
# Trying RunPod, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Databricks, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (on-demand)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (on-demand)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Salad, Price per chip-hour (on-demand)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: Inflection-2.5 ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA H100 SXM5 80GB at 2023-10-05 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -529 days +22:30:00
#
# ==== System: Claude 3 Opus ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2023-10-02 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 297 days 22:30:00
#
# ==== System: Aramco Metabrain AI ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2023-10-02 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 297 days 22:30:00
#
# ==== System: Mistral Large ====
# Trying NVIDIA H100 SXM5 80GB at 2023-07-16 20:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -610 days +20:00:00
#
# ==== System: MegaScale (Production) ====
# Trying NVIDIA A100 at 2023-10-05 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 300 days 00:00:00
#
# ==== System: Gemini 1.5 Pro ====
# No training time found, assuming 33.0625 days
#
# Trying Google TPU v4 at 2023-09-14 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2023-06-01 00:00:00
# Difference between acquisition date and price date: 105 days 22:30:00
#
# ==== System: Gemini 1.0 Ultra ====
# Trying Google TPU v4 at 2023-03-11 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-09-11 00:00:00
# Difference between acquisition date and price date: 181 days 00:00:00
#
# ==== System: Inflection-2 ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA H100 SXM5 80GB at 2023-06-21 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 4.86 at 2025-03-17 00:00:00
# Difference between acquisition date and price date: -635 days +22:30:00
#
# ==== System: GPT-4 Turbo ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2023-06-05 22:30:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Found price: 1.36 at 2022-01-20 00:00:00
# Difference between acquisition date and price date: 501 days 22:30:00
#
# ==== System: Grok-1 ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2023-06-03 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 176 days 22:30:00
#
# ==== System: Amazon Titan ====
# Trying NVIDIA A100 at 2023-04-13 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 125 days 00:00:00
#
# ==== System: Falcon-180B ====
# Trying NVIDIA A100 SXM4 40 GB at 2022-11-10 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-10-17 00:00:00
# Difference between acquisition date and price date: 24 days 00:00:00
#
# ==== System: Llama 2-70B ====
# Trying NVIDIA A100 SXM4 80 GB at 2023-01-07 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.81 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 29 days 00:00:00
#
# ==== System: Claude 2 ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2023-02-07 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 60 days 22:30:00
#
# ==== System: InternLM ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 SXM4 80 GB at 2023-02-02 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.81 at 2022-12-09 00:00:00
# Difference between acquisition date and price date: 55 days 22:30:00
#
# ==== System: xTrimoPGLM -100B ====
# Trying NVIDIA A100 SXM4 40 GB at 2022-09-26 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA A100 SXM4 40 GB to NVIDIA A100
# Found price: 1.36 at 2022-01-20 00:00:00
# Difference between acquisition date and price date: 249 days 00:00:00
#
# ==== System: PaLM 2 ====
# No training time found, assuming 33.0625 days
#
# Trying Google TPU v4 at 2022-12-07 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-09-11 00:00:00
# Difference between acquisition date and price date: 87 days 22:30:00
#
# ==== System: PanGu-Σ ====
# Trying Huawei Ascend 910 at 2022-08-12 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (on-demand)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (on-demand)
# Could not find price
#
# Trying RunPod, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Databricks, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (on-demand)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (on-demand)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Salad, Price per chip-hour (on-demand)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: GPT-4 ====
# Trying NVIDIA A100 SXM4 40 GB at 2022-03-13 00:00:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA A100 SXM4 40 GB to NVIDIA A100
# Found price: 1.36 at 2022-01-20 00:00:00
# Difference between acquisition date and price date: 52 days 00:00:00
#
# ==== System: LLaMA-65B ====
# Trying NVIDIA A100 at 2022-10-06 04:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2021-06-15 00:00:00
# Difference between acquisition date and price date: 478 days 04:00:00
#
# ==== System: GPT-3.5 ====
# Trying NVIDIA A100 SXM4 40 GB at 2022-01-13 00:00:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA A100 SXM4 40 GB to NVIDIA A100
# Found price: 1.36 at 2021-08-13 00:00:00
# Difference between acquisition date and price date: 153 days 00:00:00
#
# ==== System: BLOOM-176B ====
# Trying NVIDIA A100 SXM4 80 GB at 2021-11-16 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Found price: 1.8 at 2022-04-15 00:00:00
# Difference between acquisition date and price date: -150 days +00:00:00
#
# ==== System: Parti ====
# No training time found, assuming 33.0625 days
#
# Trying Google TPU v4 at 2022-01-19 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-05-11 00:00:00
# Difference between acquisition date and price date: -112 days +22:30:00
#
# ==== System: OPT-175B ====
# Trying NVIDIA A100 SXM4 80 GB at 2021-11-29 23:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Found price: 1.8 at 2022-04-15 00:00:00
# Difference between acquisition date and price date: -137 days +23:00:00
#
# ==== System: PaLM (540B) ====
# Trying Google TPU v4 at 2021-10-02 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-05-11 00:00:00
# Difference between acquisition date and price date: -221 days +00:00:00
#
# ==== System: Chinchilla ====
# No training time found, assuming 33.0625 days
#
# Trying Google TPU v4,Google TPU v3 at 2021-10-26 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: ST-MoE ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2021-09-16 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA A100 to NVIDIA A100
# Soft matching NVIDIA A100 to NVIDIA A100 PCIe
# Soft matching NVIDIA A100 to NVIDIA A100 SXM4 40 GB
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2021-06-15 00:00:00
# Difference between acquisition date and price date: 93 days 22:30:00
#
# ==== System: LaMDA ====
# Trying Google TPU v3 at 2021-08-16 07:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 0.9 at 2021-03-07 00:00:00
# Difference between acquisition date and price date: 162 days 07:00:00
#
# ==== System: ERNIE 3.0 Titan ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA Tesla V100 DGXS 32 GB,Huawei Ascend 910 at 2021-07-22 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (on-demand)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (on-demand)
# Could not find price
#
# Trying RunPod, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Databricks, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (on-demand)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (on-demand)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Salad, Price per chip-hour (on-demand)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: GLaM ====
# Trying Google TPU v4 at 2021-06-19 02:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2022-05-11 00:00:00
# Difference between acquisition date and price date: -326 days +02:00:00
#
# ==== System: Gopher (280B) ====
# Trying Google TPU v3 at 2021-07-02 16:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 0.9 at 2021-03-07 00:00:00
# Difference between acquisition date and price date: 117 days 16:00:00
#
# ==== System: Yuan 1.0 ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA V100 at 2021-05-11 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA V100 to NVIDIA V100
# Soft matching NVIDIA V100 to NVIDIA Tesla V100 DGXS 16 GB
# Found price: 1.23 at 2018-06-08 00:00:00
# Difference between acquisition date and price date: 1068 days 22:30:00
#
# ==== System: Megatron-Turing NLG 530B ====
# Trying NVIDIA A100 SXM4 80 GB at 2021-05-11 22:00:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Found price: 1.8 at 2022-04-15 00:00:00
# Difference between acquisition date and price date: -339 days +22:00:00
#
# ==== System: HyperCLOVA 204B ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2021-04-09 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2021-06-15 00:00:00
# Difference between acquisition date and price date: -67 days +22:30:00
#
# ==== System: Jurassic-1-Jumbo ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA A100 at 2021-03-10 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.45 at 2021-06-15 00:00:00
# Difference between acquisition date and price date: -97 days +22:30:00
#
# ==== System: ByT5-XXL ====
# No training time found, assuming 33.0625 days
#
# Trying Google TPU v3 at 2020-12-25 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 0.9 at 2020-12-02 00:00:00
# Difference between acquisition date and price date: 23 days 22:30:00
#
# ==== System: ProtT5-XXL ====
# No training time found, assuming 33.0625 days
#
# Trying Google TPU v3 at 2020-12-01 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 0.9 at 2019-12-06 00:00:00
# Difference between acquisition date and price date: 361 days 22:30:00
#
# ==== System: Meta Pseudo Labels ====
# Trying Google TPU v3 at 2020-10-21 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 0.9 at 2019-12-06 00:00:00
# Difference between acquisition date and price date: 320 days 00:00:00
#
# ==== System: Switch ====
# Trying Google TPU v3 at 2020-08-17 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 0.9 at 2019-12-06 00:00:00
# Difference between acquisition date and price date: 255 days 00:00:00
#
# ==== System: DALL-E ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA Tesla V100 DGXS 16 GB at 2020-08-04 22:30:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.23 at 2018-06-08 00:00:00
# Difference between acquisition date and price date: 788 days 22:30:00
#
# ==== System: mT5-XXL ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA Tesla V100 DGXS 32 GB at 2020-05-19 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA Tesla V100 DGXS 32 GB to NVIDIA V100
# Found price: 1.12 at 2025-03-03 00:00:00
# Difference between acquisition date and price date: -1749 days +22:30:00
#
# ==== System: GShard (dense) ====
# Trying Google TPU v3 at 2020-01-20 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 0.9 at 2019-12-06 00:00:00
# Difference between acquisition date and price date: 45 days 00:00:00
#
# ==== System: iGPT-XL ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA Tesla V100 DGXS 32 GB at 2020-01-15 22:30:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA Tesla V100 DGXS 32 GB to NVIDIA V100
# Found price: 1.16 at 2019-11-18 00:00:00
# Difference between acquisition date and price date: 58 days 22:30:00
#
# ==== System: GPT-3 175B (davinci) ====
# Trying NVIDIA Tesla V100 DGXS 32 GB at 2019-08-02 00:00:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA Tesla V100 DGXS 32 GB to NVIDIA V100
# Found price: 1.16 at 2018-12-30 00:00:00
# Difference between acquisition date and price date: 215 days 00:00:00
#
# ==== System: Meena ====
# Trying Google TPU v3 at 2019-08-31 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 0.9 at 2019-08-31 00:00:00
# Difference between acquisition date and price date: 0 days 00:00:00
#
# ==== System: OpenAI Five ====
# Trying NVIDIA P100 at 2018-10-23 00:00:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Found price: 0.92 at 2018-12-30 00:00:00
# Difference between acquisition date and price date: -68 days +00:00:00
#
# ==== System: OpenAI Five Rerun ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA P100 at 2019-07-12 22:30:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Found price: 0.92 at 2018-12-30 00:00:00
# Difference between acquisition date and price date: 194 days 22:30:00
#
# ==== System: Noisy Student (L2) ====
# Trying Google TPU v3 at 2019-07-08 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Found price: 0.9 at 2019-07-01 00:00:00
# Difference between acquisition date and price date: 7 days 00:00:00
#
# ==== System: XLM-RoBERTa ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA Tesla V100 DGXS 32 GB at 2019-06-04 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.21 at 2019-05-20 00:00:00
# Difference between acquisition date and price date: 15 days 22:30:00
#
# ==== System: AlphaStar ====
# Trying Google TPU v3 at 2019-05-19 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Applying CUD: 2.0 * 0.43999999999999995 = 0.8799999999999999
# Found price: 0.8799999999999999 at 2018-10-11 00:00:00
# Difference between acquisition date and price date: 220 days 00:00:00
#
# ==== System: T5-3B ====
# No training time found, assuming 33.0625 days
#
# Trying Google TPU v3 at 2019-05-22 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Applying CUD: 2.0 * 0.43999999999999995 = 0.8799999999999999
# Found price: 0.8799999999999999 at 2018-10-11 00:00:00
# Difference between acquisition date and price date: 223 days 22:30:00
#
# ==== System: T5-11B ====
# Trying Google TPU v3 at 2019-06-04 23:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Applying CUD: 2.0 * 0.43999999999999995 = 0.8799999999999999
# Found price: 0.8799999999999999 at 2018-10-11 00:00:00
# Difference between acquisition date and price date: 236 days 23:00:00
#
# ==== System: Megatron-BERT ====
# Trying NVIDIA Tesla V100S PCIe 32 GB at 2019-05-04 10:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA Tesla V100S PCIe 32 GB to NVIDIA V100
# Soft matching NVIDIA Tesla V100S PCIe 32 GB to NVIDIA Tesla V100 DGXS 16 GB
# Found price: 1.23 at 2018-06-08 00:00:00
# Difference between acquisition date and price date: 330 days 10:00:00
#
# ==== System: Megatron-LM (8.3B) ====
# Trying NVIDIA Tesla V100 DGXS 32 GB at 2019-05-06 09:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.21 at 2019-04-05 00:00:00
# Difference between acquisition date and price date: 31 days 09:00:00
#
# ==== System: RoBERTa Large ====
# Trying NVIDIA Tesla V100 DGXS 32 GB at 2019-02-26 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 1.21 at 2019-01-25 00:00:00
# Difference between acquisition date and price date: 32 days 00:00:00
#
# ==== System: XLNet ====
# No training time found, assuming 33.0625 days
#
# Trying Google TPU v3 at 2018-12-29 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Applying CUD: 2.0 * 0.43999999999999995 = 0.8799999999999999
# Found price: 0.8799999999999999 at 2018-10-11 00:00:00
# Difference between acquisition date and price date: 79 days 22:30:00
#
# ==== System: MnasNet-A3 ====
# Trying Google TPU v3 at 2019-01-24 12:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Applying CUD: 2.0 * 0.43999999999999995 = 0.8799999999999999
# Found price: 0.8799999999999999 at 2018-10-11 00:00:00
# Difference between acquisition date and price date: 105 days 12:00:00
#
# ==== System: GPT-2 (1.5B) ====
# No training time found, assuming 33.0625 days
#
# Trying Google TPU v3 at 2018-09-13 22:30:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Applying CUD: 2.0 * 0.43999999999999995 = 0.8799999999999999
# Found price: 0.8799999999999999 at 2018-10-11 00:00:00
# Difference between acquisition date and price date: -28 days +22:30:00
#
# ==== System: BigGAN-deep 512x512 ====
# Trying Google TPU v3 at 2018-05-29 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Applying CUD: 2.0 * 0.43999999999999995 = 0.8799999999999999
# Found price: 0.8799999999999999 at 2018-10-11 00:00:00
# Difference between acquisition date and price date: -135 days +00:00:00
#
# ==== System: ResNeXt-101 32x48d ====
# Trying NVIDIA V100 at 2017-12-12 08:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Soft matching NVIDIA V100 to NVIDIA V100
# Soft matching NVIDIA V100 to NVIDIA Tesla V100 DGXS 16 GB
# Found price: 1.23 at 2018-06-08 00:00:00
# Difference between acquisition date and price date: -178 days +08:00:00
#
# ==== System: AlphaZero ====
# Trying Google TPU v2,Google TPU v1 at 2017-08-06 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: AlphaGo Master ====
# Trying Google TPU v1 at 2017-06-18 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: AlphaGo Zero ====
# Trying Google TPU v1 at 2017-05-31 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: Libratus ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA M40 at 2017-03-18 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (on-demand)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (on-demand)
# Could not find price
#
# Trying RunPod, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Databricks, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (on-demand)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (on-demand)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Salad, Price per chip-hour (on-demand)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: OpenAI TI7 DOTA 1v1 ====
# No training time found, assuming 33.0625 days
#
# Trying NVIDIA M40 at 2017-03-10 22:30:00
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying RunPod, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Databricks, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Salad, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Paperspace, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Jarvislabs, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Datacrunch, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Exoscale, Price per chip-hour (on-demand)
# Could not find price
#
# Trying OVHcloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Cudo Compute, Price per chip-hour (on-demand)
# Could not find price
#
# Trying RunPod, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oblivus Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Databricks, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Latitude.sh, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Oracle Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying FluidStack, Price per chip-hour (on-demand)
# Could not find price
#
# Trying NovoNimbus, Price per chip-hour (on-demand)
# Could not find price
#
# Trying CR8DL, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Salad, Price per chip-hour (on-demand)
# Could not find price
#
# Trying vast.ai, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: JFT ====
# Trying NVIDIA Tesla K80 at 2017-01-11 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 0.43 at 2017-02-10 00:00:00
# Difference between acquisition date and price date: -30 days +00:00:00
#
# ==== System: MoE-Multi ====
# Trying NVIDIA Tesla K40t at 2016-09-13 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# ...
# Could not find hardware model for OpenAI TI7 DOTA 1v1
#
# ==== System: JFT ====
# Estimated the value of NVIDIA Tesla K80 server, available from 2015-02-15 00:00:00 and used from 2017-03-12 00:00:00: 4207.651141617478 per chip
#
# ==== System: MoE-Multi ====
# Estimated the value of NVIDIA Tesla K40t server, available from 2014-02-20 00:00:00 and used from 2016-11-12 00:00:00: 3676.8142833011802 per chip
#
# ==== System: PolyNet ====
# No training time found, assuming 33.0625 days
#
# Estimated the value of NVIDIA GeForce GTX TITAN X server, available from 2015-06-15 00:00:00 and used from 2016-08-15 22:30:00: 1123.93350055616 per chip
#
# ==== System: NASv3 (CIFAR-10) ====
# Could not find hardware model for NASv3 (CIFAR-10)
#
# ==== System: Xception ====
# Estimated the value of NVIDIA Tesla K80 server, available from 2015-02-15 00:00:00 and used from 2016-07-09 00:00:00: 5227.948565540916 per chip
#
# ==== System: GNMT ====
# No training time found, assuming 33.0625 days
#
# Estimated the value of NVIDIA Tesla K80 server, available from 2015-02-15 00:00:00 and used from 2016-06-24 22:30:00: 5297.619876078356 per chip
#
# ==== System: ResNet-200 ====
# Could not find hardware model for ResNet-200
#
# ==== System: AlphaGo Lee ====
# Could not find hardware model for AlphaGo Lee
#
# ==== System: ResNet-152 (ImageNet) ====
# Could not find hardware model for ResNet-152 (ImageNet)
#
# ==== System: DeepSpeech2 (English) ====
# Estimated the value of NVIDIA GeForce GTX TITAN X server, available from 2015-06-15 00:00:00 and used from 2015-10-04 00:00:00: 1485.4674335348793 per chip
#
# ==== System: Inception v3 ====
# Could not find hardware model for Inception v3
#
# ==== System: Llama 4 Behemoth (preview) ====
# Unable to estimate cost
# ==== System: GPT-4.5 ====
# Unable to estimate cost
# ==== System: Claude 3.7 Sonnet ====
# Unable to estimate cost
# ==== System: Grok-3 ====
# Overall cost per chip-hour for NVIDIA H100 SXM5 80GB: 1.2560615441997975
# Estimated cost: 301454770.6079514
# ==== System: Doubao-pro ====
# Unable to estimate cost
# ==== System: GLM-4-Plus ====
# Unable to estimate cost
# ==== System: Grok-2 ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 SXM5 80GB at 989400000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA H100 SXM5 80GB: 1.3810586019195163
# Estimated cost: 30605405.907671448
# ==== System: Mistral Large 2 ====
# Unable to estimate cost
# ==== System: Llama 3.1-405B ====
# Overall cost per chip-hour for NVIDIA H100 SXM5 80GB: 1.4606362604801284
# Estimated cost: 51260340.14123516
# ==== System: Claude 3.5 Sonnet ====
# Unable to estimate cost
# ==== System: Nemotron-4 340B ====
# Overall cost per chip-hour for NVIDIA H100 SXM5 80GB: 1.522529017347931
# Estimated cost: 20579720.221688513
# ==== System: GPT-4o ====
# Unable to estimate cost
# ==== System: Reka Core ====
# Unable to estimate cost
# ==== System: Inflection-2.5 ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 SXM5 80GB at 989400000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA H100 SXM5 80GB: 1.5752358846255168
# Estimated cost: 11794603.599742299
# ==== System: Claude 3 Opus ====
# Unable to estimate cost
# ==== System: Aramco Metabrain AI ====
# Unable to estimate cost
# ==== System: Mistral Large ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 SXM5 80GB at 989400000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA H100 SXM5 80GB: 1.6851411234008977
# Estimated cost: 14130210.289880175
# ==== System: MegaScale (Production) ====
# Overall cost per chip-hour for NVIDIA A100: 0.4226834151745655
# Estimated cost: 2617742.6380551904
# ==== System: Gemini 1.5 Pro ====
# Imputing training time from compute and hardware
# Found Google TPU v4 at 275000000000000.0 FLOP/s
# Overall cost per chip-hour for Google TPU v4: 0.1824489210578188
# Estimated cost: 7764834.416707736
# ==== System: Gemini 1.0 Ultra ====
# Overall cost per chip-hour for Google TPU v4: 0.2138916665308779
# Estimated cost: 28233699.982075885
# ==== System: Inflection-2 ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 SXM5 80GB at 989400000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA H100 SXM5 80GB: 1.724863665305324
# Estimated cost: 12926566.261412673
# ==== System: GPT-4 Turbo ====
# Unable to estimate cost
# ==== System: Grok-1 ====
# Unable to estimate cost
# ==== System: Amazon Titan ====
# Overall cost per chip-hour for NVIDIA A100: 0.4787689007505894
# Estimated cost: 7589214.8056259835
# ==== System: Falcon-180B ====
# Overall cost per chip-hour for NVIDIA A100 SXM4 40 GB: 0.5808126699327456
# Estimated cost: 10277317.566912353
# ==== System: Llama 2-70B ====
# Overall cost per chip-hour for NVIDIA A100 SXM4 80 GB: 0.6355669272024409
# Estimated cost: 1093378.4962049031
# ==== System: Claude 2 ====
# Unable to estimate cost
# ==== System: InternLM ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 SXM4 80 GB at 312000000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA A100 SXM4 80 GB: 0.6297415952911269
# Estimated cost: 1492720.8184678564
# ==== System: xTrimoPGLM -100B ====
# Overall cost per chip-hour for NVIDIA A100 SXM4 40 GB: 0.6018570384413092
# Estimated cost: 1808228.9160056845
# ==== System: PaLM 2 ====
# Imputing training time from compute and hardware
# Found Google TPU v4 at 275000000000000.0 FLOP/s
# Overall cost per chip-hour for Google TPU v4: 0.23151893997401143
# Estimated cost: 4577371.096051835
# ==== System: PanGu-Σ ====
# Unable to estimate cost
# ==== System: GPT-4 ====
# Overall cost per chip-hour for NVIDIA A100 SXM4 40 GB: 0.7044900692075396
# Estimated cost: 40155933.94482976
# ==== System: LLaMA-65B ====
# Overall cost per chip-hour for NVIDIA A100: 0.5558708526179696
# Estimated cost: 569211.7530808009
# ==== System: GPT-3.5 ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 SXM4 40 GB at 312000000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA A100 SXM4 40 GB: 0.7408451176583034
# Estimated cost: 4534422.3963036705
# ==== System: BLOOM-176B ====
# Overall cost per chip-hour for NVIDIA A100 SXM4 80 GB: 0.9036377801483829
# Estimated cost: 974367.3164761572
# ==== System: Parti ====
# Imputing training time from compute and hardware
# Found Google TPU v4 at 275000000000000.0 FLOP/s
# Overall cost per chip-hour for Google TPU v4: 0.30461892904218485
# Estimated cost: 418144.71029149706
# ==== System: OPT-175B ====
# Overall cost per chip-hour for NVIDIA A100 SXM4 80 GB: 0.8864471003715254
# Estimated cost: 720277.2727242807
# ==== System: PaLM (540B) ====
# Overall cost per chip-hour for Google TPU v4: 0.33432559235325604
# Estimated cost: 2810003.929124378
# ==== System: Chinchilla ====
# Unable to estimate cost
# ==== System: ST-MoE ====
# Unable to estimate cost
# ==== System: LaMDA ====
# Overall cost per chip-hour for Google TPU v3: 0.1435291946653405
# Estimated cost: 203558.84504217253
# ==== System: ERNIE 3.0 Titan ====
# Unable to estimate cost
# ==== System: GLaM ====
# Overall cost per chip-hour for Google TPU v4: 0.36434536122104033
# Estimated cost: 509640.46175021166
# ==== System: Gopher (280B) ====
# Overall cost per chip-hour for Google TPU v3: 0.14708484587134846
# Estimated cost: 554262.7663939198
# ==== System: Yuan 1.0 ====
# Unable to estimate cost
# ==== System: Megatron-Turing NLG 530B ====
# Overall cost per chip-hour for NVIDIA A100 SXM4 80 GB: 1.0409213280892418
# Estimated cost: 3590762.2133766487
# ==== System: HyperCLOVA 204B ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 at 312000000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA A100: 0.8665239585772426
# Estimated cost: 411454.87113987125
# ==== System: Jurassic-1-Jumbo ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 at 312000000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA A100: 0.8883062411862271
# Estimated cost: 780325.9953440267
# ==== System: ByT5-XXL ====
# Imputing training time from compute and hardware
# Found Google TPU v3 at 123000000000000.0 FLOP/s
# Overall cost per chip-hour for Google TPU v3: 0.17179094051578767
# Estimated cost: 83800.4587881891
# ==== System: ProtT5-XXL ====
# Imputing training time from compute and hardware
# Found Google TPU v3 at 123000000000000.0 FLOP/s
# Overall cost per chip-hour for Google TPU v3: 0.17523348550321247
# Estimated cost: 77776.01855818585
# ==== System: Meta Pseudo Labels ====
# Overall cost per chip-hour for Google TPU v3: 0.1812858494523124
# Estimated cost: 49008.09139754033
# ==== System: Switch ====
# Overall cost per chip-hour for Google TPU v3: 0.1913413859354782
# Estimated cost: 126964.95932025842
# ==== System: DALL-E ====
# Imputing training time from compute and hardware
# Found NVIDIA Tesla V100 DGXS 16 GB at 125000000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA Tesla V100 DGXS 16 GB: 0.43414591237056943
# Estimated cost: 120917.67633432157
# ==== System: mT5-XXL ====
# Unable to estimate cost
# ==== System: GShard (dense) ====
# Overall cost per chip-hour for Google TPU v3: 0.22728750715577395
# Estimated cost: 234604.34658613263
# ==== System: iGPT-XL ====
# Imputing training time from compute and hardware
# Found NVIDIA Tesla V100 DGXS 32 GB at 125000000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA Tesla V100 DGXS 32 GB: 0.5114084272339049
# Estimated cost: 100008.75910351919
# ==== System: GPT-3 175B (davinci) ====
# Overall cost per chip-hour for NVIDIA Tesla V100 DGXS 32 GB: 0.5879896224222146
# Estimated cost: 2088539.1388437063
# ==== System: Meena ====
# Overall cost per chip-hour for Google TPU v3: 0.25627222901761204
# Estimated cost: 188944.389010105
# ==== System: OpenAI Five ====
# Overall cost per chip-hour for NVIDIA P100: 0.35925480188607195
# Estimated cost: 3920096.4289515344
# ==== System: OpenAI Five Rerun ====
# Imputing training time from compute and hardware
# Found NVIDIA P100 at 9300000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA P100: 0.29101869958034216
# Estimated cost: 301333.57981238136
# ==== System: Noisy Student (L2) ====
# Overall cost per chip-hour for Google TPU v3: 0.2684978163857718
# Estimated cost: 39591.61401298037
# ==== System: XLM-RoBERTa ====
# Imputing training time from compute and hardware
# Found NVIDIA Tesla V100 DGXS 32 GB at 125000000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA Tesla V100 DGXS 32 GB: 0.6153807136398896
# Estimated cost: 75705.50290467619
# ==== System: AlphaStar ====
# Overall cost per chip-hour for Google TPU v3: 0.28014166948459396
# Estimated cost: 113598.56754268079
# ==== System: T5-3B ====
# Imputing training time from compute and hardware
# Found Google TPU v3 at 123000000000000.0 FLOP/s
# Overall cost per chip-hour for Google TPU v3: 0.27942845462029453
# Estimated cost: 15145.173692325163
# ==== System: T5-11B ====
# Overall cost per chip-hour for Google TPU v3: 0.2763595856513102
# Estimated cost: 68187.02964650471
# ==== System: Megatron-BERT ====
# Overall cost per chip-hour for NVIDIA Tesla V100S PCIe 32 GB: 0.8721792616887812
# Estimated cost: 167011.86246226134
# ==== System: Megatron-LM (8.3B) ====
# Overall cost per chip-hour for NVIDIA Tesla V100 DGXS 32 GB: 0.6339198437504425
# Estimated cost: 106133.3959200741
# ==== System: RoBERTa Large ====
# Overall cost per chip-hour for NVIDIA Tesla V100 DGXS 32 GB: 0.6688614374710711
# Estimated cost: 82189.69343644522
# ==== System: XLNet ====
# Imputing training time from compute and hardware
# Found Google TPU v3 at 123000000000000.0 FLOP/s
# Overall cost per chip-hour for Google TPU v3: 0.31588506847827724
# Estimated cost: 11775.540944778899
# ==== System: MnasNet-A3 ====
# Overall cost per chip-hour for Google TPU v3: 0.3089552937718668
# Estimated cost: 8541.995962204574
# ==== System: GPT-2 (1.5B) ====
# Imputing training time from compute and hardware
# Found Google TPU v3 at 123000000000000.0 FLOP/s
# Overall cost per chip-hour for Google TPU v3: 0.3475587489357624
# Estimated cost: 4018.746148491486
# ==== System: BigGAN-deep 512x512 ====
# Overall cost per chip-hour for Google TPU v3: 0.37955589309144605
# Estimated cost: 4663.982814307689
# ==== System: ResNeXt-101 32x48d ====
# Overall cost per chip-hour for NVIDIA V100: 0.7732057248383212
# Estimated cost: 128859.37327865526
# ==== System: AlphaZero ====
# Unable to estimate cost
# ==== System: AlphaGo Master ====
# Imputing training time from compute and hardware
# Overall cost per chip-hour for Google TPU v1: 0.20353719119592392
# Estimated cost: 327773.5395418434
# ==== System: AlphaGo Zero ====
# Imputing training time from compute and hardware
# Overall cost per chip-hour for Google TPU v1: 0.20668197493817955
# Estimated cost: 567460.1727368698
# ==== System: Libratus ====
# Unable to estimate cost
# ==== System: OpenAI TI7 DOTA 1v1 ====
# Unable to estimate cost
# ==== System: JFT ====
# Overall cost per chip-hour for NVIDIA Tesla K80: 0.2216783716143869
# Estimated cost: 15960.842756235856
# ==== System: MoE-Multi ====
# Overall cost per chip-hour for NVIDIA Tesla K40t: 0.19195906131641663
# Estimated cost: 3538.1894181841913
# ==== System: PolyNet ====
# Imputing training time from compute and hardware
# Found NVIDIA GeForce GTX TITAN X at 6691000000000.0 FLOP/s
# Overall cost per chip-hour for NVIDIA GeForce GTX TITAN X: 0.07954549380893801
# Estimated cost: 563.5997059368894
# ==== System: NASv3 (CIFAR-10) ====
# Unable to estimate cost
# ==== System: Xception ====
# Overall cost per chip-hour for NVIDIA Tesla K80: 0.2674654225249599
# Estimated cost: 11554.506253078269
# ==== System: GNMT ====
# Overall cost per chip-hour for NVIDIA Tesla K80: 0.2706285101203272
# Estimated cost: 177459.23294120215
# ==== System: ResNet-200 ====
# Unable to estimate cost
# ==== System: AlphaGo Lee ====
# Unable to estimate cost
# ==== System: ResNet-152 (ImageNet) ====
# Unable to estimate cost
# ==== System: DeepSpeech2 (English) ====
# Overall cost per chip-hour for NVIDIA GeForce GTX TITAN X: 0.09659199926071341
# Estimated cost: 185.45663858056975
# ==== System: Inception v3 ====
# Unable to estimate cost
# All costs:
# {'Grok-3': 301454770.6079514, 'Grok-2': 30605405.907671448, 'Llama 3.1-405B': 51260340.14123516, 'Nemotron-4 340B': 20579720.221688513, 'Inflection-2.5': 11794603.599742299, 'Mistral Large': 14130210.289880175, 'MegaScale (Production)': 2617742.6380551904, 'Gemini 1.5 Pro': 7764834.416707736, 'Gemini 1.0 Ultra': 28233699.982075885, 'Inflection-2': 12926566.261412673, 'Amazon Titan': 7589214.8056259835, 'Falcon-180B': 10277317.566912353, 'Llama 2-70B': 1093378.4962049031, 'InternLM': 1492720.8184678564, 'xTrimoPGLM -100B': 1808228.9160056845, 'PaLM 2': 4577371.096051835, 'GPT-4': 40155933.94482976, 'LLaMA-65B': 569211.7530808009, 'GPT-3.5': 4534422.3963036705, 'BLOOM-176B': 974367.3164761572, 'Parti': 418144.71029149706, 'OPT-175B': 720277.2727242807, 'PaLM (540B)': 2810003.929124378, 'LaMDA': 203558.84504217253, 'GLaM': 509640.46175021166, 'Gopher (280B)': 554262.7663939198, 'Megatron-Turing NLG 530B': 3590762.2133766487, 'HyperCLOVA 204B': 411454.87113987125, 'Jurassic-1-Jumbo': 780325.9953440267, 'ByT5-XXL': 83800.4587881891, 'ProtT5-XXL': 77776.01855818585, 'Meta Pseudo Labels': 49008.09139754033, 'Switch': 126964.95932025842, 'DALL-E': 120917.67633432157, 'GShard (dense)': 234604.34658613263, 'iGPT-XL': 100008.75910351919, 'GPT-3 175B (davinci)': 2088539.1388437063, 'Meena': 188944.389010105, 'OpenAI Five': 3920096.4289515344, 'OpenAI Five Rerun': 301333.57981238136, 'Noisy Student (L2)': 39591.61401298037, 'XLM-RoBERTa': 75705.50290467619, 'AlphaStar': 113598.56754268079, 'T5-3B': 15145.173692325163, 'T5-11B': 68187.02964650471, 'Megatron-BERT': 167011.86246226134, 'Megatron-LM (8.3B)': 106133.3959200741, 'RoBERTa Large': 82189.69343644522, 'XLNet': 11775.540944778899, 'MnasNet-A3': 8541.995962204574, 'GPT-2 (1.5B)': 4018.746148491486, 'BigGAN-deep 512x512': 4663.982814307689, 'ResNeXt-101 32x48d': 128859.37327865526, 'AlphaGo Master': 327773.5395418434, 'AlphaGo Zero': 567460.1727368698, 'JFT': 15960.842756235856, 'MoE-Multi': 3538.1894181841913, 'PolyNet': 563.5997059368894, 'Xception': 11554.506253078269, 'GNMT': 177459.23294120215, 'DeepSpeech2 (English)': 185.45663858056975}
# Models with missing critical data (pre-imputation): 50
# Models with successful cost estimates WITHOUT imputation: 61
# Models with successful cost estimates WITH imputation (hardware-capex-energy): 82
# ✓ Imputation enabled cost estimation for 21 additional models

# %%
# Combine results from all methods into a single CSV with 4 columns
print(f"\n{'='*60}")
print("COMBINING RESULTS FROM ALL METHODS")
print(f"{'='*60}")

# Get all unique models from all methods
all_models = set()
for method_df in method_results.values():
    all_models.update(method_df['Model'].tolist())

print(f"Total unique models across all methods: {len(all_models)}")

# Create the combined results DataFrame
combined_results = pd.DataFrame({'Model': sorted(all_models)})

# Add cost columns for each method
method_column_names = {
    'cloud': 'Cloud_Cost',
    'hardware-acquisition': 'Hardware_Acquisition_Cost', 
    'hardware-capex-energy': 'Hardware_Capex_Energy_Cost'
}

for method, column_name in method_column_names.items():
    method_df = method_results[method]
    if len(method_df) > 0:
        # Create a mapping from model to cost
        model_to_cost = method_df.set_index('Model')['Cost (inflation-adjusted)'].to_dict()
        combined_results[column_name] = combined_results['Model'].map(model_to_cost)
    else:
        combined_results[column_name] = None

# Save combined results
combined_results.to_csv(output_file, index=False)
print(f"\nCombined results saved to {output_file}")

# Display statistics for the combined dataset
print(f"\nCombined Dataset Statistics:")
print(f"Total models: {len(combined_results)}")

for method, column_name in method_column_names.items():
    valid_costs = combined_results[column_name].notna()
    count = valid_costs.sum()
    print(f"\n{method} method ({column_name}):")
    print(f"  Models with estimates: {count}")
    if count > 0:
        costs = combined_results[column_name].dropna()
        print(f"  Min: ${costs.min():,.0f}")
        print(f"  Max: ${costs.max():,.0f}")
        print(f"  Median: ${costs.median():,.0f}")
        print(f"  Mean: ${costs.mean():,.0f}")

# Show models with estimates from all three methods
all_methods_valid = (
    combined_results['Cloud_Cost'].notna() & 
    combined_results['Hardware_Acquisition_Cost'].notna() & 
    combined_results['Hardware_Capex_Energy_Cost'].notna()
)
models_with_all_methods = combined_results[all_methods_valid]

print(f"\nModels with estimates from all three methods: {len(models_with_all_methods)}")
if len(models_with_all_methods) > 0:
    print("Top 5 models by Hardware_Capex_Energy_Cost:")
    top_models = models_with_all_methods.nlargest(5, 'Hardware_Capex_Energy_Cost')
    for i, (_, row) in enumerate(top_models.iterrows()):
        print(f"{i+1}. {row['Model']}")
        print(f"   Cloud: ${row['Cloud_Cost']:,.0f}")
        print(f"   Hardware Acquisition: ${row['Hardware_Acquisition_Cost']:,.0f}")
        print(f"   Hardware Capex+Energy: ${row['Hardware_Capex_Energy_Cost']:,.0f}")

# Show preview of the CSV structure
print(f"\nCSV Preview (first 5 rows):")
print(combined_results.head().to_string(index=False, float_format='%.0f'))

# Final validation report
print(f"\n{'='*60}")
print("FINAL VALIDATION REPORT")
print(f"{'='*60}")
print(f"Configuration used:")
print(f"  Compute threshold method: {compute_threshold_method}")
print(f"  Compute threshold: {compute_threshold}")
print(f"  Imputation enabled: {enable_imputation}")
if enable_imputation:
    print(f"  Imputation method: {imputation_method}")
    if imputation_method == 'knn':
        print(f"  KNN neighbors: {knn_neighbors}")

print(f"\nOutput file: {output_file}")
print(f"Total models: {len(combined_results)}")
print(f"Columns: {list(combined_results.columns)}")

# Data quality warnings
total_possible_estimates = len(combined_results) * 3
total_actual_estimates = (
    combined_results['Cloud_Cost'].notna().sum() +
    combined_results['Hardware_Acquisition_Cost'].notna().sum() +
    combined_results['Hardware_Capex_Energy_Cost'].notna().sum()
)
success_rate = total_actual_estimates / total_possible_estimates * 100

print(f"\nOverall success rate: {success_rate:.1f}% ({total_actual_estimates}/{total_possible_estimates} estimates)")

if success_rate < 50:
    print("⚠️  Warning: Low success rate. Consider enabling imputation or reviewing data quality")
else:
    print("✅ Good success rate for cost estimation")

print(f"\n✅ Multi-method cost estimation complete. Results saved to {output_file}")
# Out:
# ============================================================
# COMBINING RESULTS FROM ALL METHODS
# ============================================================
# Total unique models across all methods: 82
#
# Combined results saved to model_costs.csv
#
# Combined Dataset Statistics:
# Total models: 82
#
# cloud method (Cloud_Cost):
#   Models with estimates: 35
#   Min: $11,679
#   Max: $1,164,146,794
#   Median: $1,507,793
#   Mean: $51,252,409
#
# hardware-acquisition method (Hardware_Acquisition_Cost):
#   Models with estimates: 46
#   Min: $36,098
#   Max: $5,481,967,429
#   Median: $12,590,292
#   Mean: $260,801,191
#
# hardware-capex-energy method (Hardware_Capex_Energy_Cost):
#   Models with estimates: 82
#   Min: $122
#   Max: $300,872,432
#   Median: $558,202
#   Mean: $12,525,155
#
# Models with estimates from all three methods: 35
# Top 5 models by Hardware_Capex_Energy_Cost:
# 1. Grok-3
#    Cloud: $1,164,146,794
#    Hardware Acquisition: $5,481,967,429
#    Hardware Capex+Energy: $300,872,432
# 2. Llama 3.1-405B
#    Cloud: $169,828,008
#    Hardware Acquisition: $896,044,949
#    Hardware Capex+Energy: $51,040,524
# 3. GPT-4
#    Cloud: $78,562,017
#    Hardware Acquisition: $778,066,899
#    Hardware Capex+Energy: $40,695,706
# 4. Gemini 1.0 Ultra
#    Cloud: $198,893,275
#    Hardware Acquisition: $597,913,206
#    Hardware Capex+Energy: $28,309,604
# 5. Nemotron-4 340B
#    Cloud: $65,529,676
#    Hardware Acquisition: $336,631,911
#    Hardware Capex+Energy: $20,528,978
#
# CSV Preview (first 5 rows):
#          Model  Cloud_Cost  Hardware_Acquisition_Cost  Hardware_Capex_Energy_Cost
#    AlphaGo Lee         NaN                        NaN                       21432
# AlphaGo Master         NaN                        NaN                      355308
#   AlphaGo Zero         NaN                        NaN                      615130
#      AlphaStar      381279                    4382889                      121378
#   Amazon Titan    23189104                  426325743                     7656705
#
# ============================================================
# FINAL VALIDATION REPORT
# ============================================================
# Configuration used:
#   Compute threshold method: top_n
#   Compute threshold: 10
#   Imputation enabled: True
#   Imputation method: most_common
#
# Output file: model_costs.csv
# Total models: 82
# Columns: ['Model', 'Cloud_Cost', 'Hardware_Acquisition_Cost', 'Hardware_Capex_Energy_Cost']
#
# Overall success rate: 66.3% (163/246 estimates)
# ✅ Good success rate for cost estimation
#
# ✅ Multi-method cost estimation complete. Results saved to model_costs.csv
