# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from contextlib import redirect_stdout
import numpy as np
import os
import pandas as pd
import plotly.express as px

from cost import *
from plotting import *
from prices import *
from imputation import *
from inflation import *
from regression import *
from utils import *

# %%
estimation_method = 'cloud'
compute_threshold_method = 'top_n'  # top_n, window_percentile
compute_threshold = 10  # e.g. 10 to select top 10; 75 to select top 25%
variant = 'original'
exclude_models_containing = []

estimation_method_lookup = {
    'cloud': estimate_cloud_costs,
    'amortized': estimate_amortized_hardware_costs,
    'hardware-acquisition': estimate_hardware_acquisition_cost,
    'hardware-capex-opex': estimate_hardware_capex_opex,
}
cost_estimation_function = estimation_method_lookup[estimation_method]

results_dir = f'results/{estimation_method}-{compute_threshold_method}={compute_threshold}-{variant}/'
os.makedirs(results_dir, exist_ok=True)

# %% [markdown]
# # Load data

# %%
frontier_pcd_df, hardware_df, price_df = load_data_for_cost_estimation(
    compute_threshold_method=compute_threshold_method, compute_threshold=compute_threshold,
)

# %%
len(frontier_pcd_df), len(hardware_df), len(price_df)
# Out:
# (67, 5510, 142)

# %%
# load the data on all models
all_models = pd.read_csv("https://epochai.org/data/epochdb/all_systems.csv", dtype={'Training compute (FLOP)': 'float64'})
all_models['Decimal year'] = pd.to_datetime(all_models['Publication date']).dt.year + (pd.to_datetime(all_models['Publication date']).dt.month - 1) / 12 + (pd.to_datetime(all_models['Publication date']).dt.day - 1) / 365
all_models.sort_values(by='Decimal year', inplace=True)
# all_models.dropna(subset='Training compute (FLOP)', inplace=True)
all_models = all_models[all_models['Confidence'] != 'Wrong']
all_models = all_models[all_models['System'] != 'λ-WASP']
all_models = all_models[all_models['System'] != 'DOC + Finetune∗ + Partial Shuffle (WT2)']
all_models = all_models[all_models['System'] != 'DOC + Finetune∗ + Partial Shuffle (PTB)']
all_models = all_models[all_models['System'] != 'PanGu-α']
all_models = all_models[all_models['System'] != 'PIXART-α']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GeForce GTX 580']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GeForce GTX 780']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GeForce GTX 980']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GeForce GTX 1080']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GeForce GTX 1080 Ti']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GeForce RTX 2080 Ti']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GeForce RTX 3090']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA Geforce GTX1080 Ti']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA Geforce GTX 1080 Ti']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA TITAN Xp']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GeForce GTX TITAN']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GeForce GTX TITAN X']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA GTX Titan Black']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA Titan V']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA M40']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA Quadro P600']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA Quadro RTX 5000']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA Quadro RTX 4000']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA Quadro RTX 8000']
all_models = all_models[all_models['Training hardware'] != 'Huawei Ascend 910']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA RTX A6000']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA RTX A5000']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA A10 PCIe']
all_models = all_models[all_models['Training hardware'] != 'NVIDIA A800']
all_models = all_models[all_models['Training hardware'] != 'AMD Instinct MI250X']
all_models = all_models[all_models['Training hardware'] != 'Cerebras CS-2']
all_models = all_models[all_models['Training hardware'] != 'Google TPU v5e']
all_models = all_models[all_models['Training hardware'] != 'Google TPU v5p']



# Replace frontier model df with all models
frontier_pcd_df = all_models.copy()

# %% [markdown]
# # Cost estimation

# %%
cost_df = cost_estimation_function(frontier_pcd_df, hardware_df, price_df)
# Out:
# ==== System: Theseus ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Theseus
#
#
# ==== System: SNARC ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SNARC
#
#
# ==== System: Genetic algorithm ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Genetic algorithm
#
#
# ==== System: Self Organizing System ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Self Organizing System
#
#
# ==== System: Sequence-based pattern recognition ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Sequence-based pattern recognition
#
#
# ==== System: Conditional probability machines ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Conditional probability machines
#
#
# ==== System: Perceptron Mark I ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Perceptron Mark I
#
#
# ==== System: Pandemonium (morse) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Pandemonium (morse)
#
#
# ==== System: Samuel Neural Checkers ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Samuel Neural Checkers
#
#
# ==== System: Pattern recognition and reading by machine ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Pattern recognition and reading by machine
#
#
# ==== System: Perceptron (1960) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Perceptron (1960)
#
#
# ==== System: ADALINE ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ADALINE
#
#
# ==== System: LMS ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LMS
#
#
# ==== System: Heuristic problem solving for AI ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Heuristic problem solving for AI
#
#
# ==== System: PAPA ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for PAPA
#
#
# ==== System: Linear Decision Functions ====
# Could not find hardware model for Linear Decision Functions
#
#
# ==== System: MADALINE I ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for MADALINE I
#
#
# ==== System: Print Recognition Logic ====
# Could not find hardware model for Print Recognition Logic
#
#
# ==== System: STeLLA ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for STeLLA
#
#
# ==== System: MENACE ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for MENACE
#
#
# ==== System: Heuristic Reinforcement Learning ====
# Could not find hardware model for Heuristic Reinforcement Learning
#
#
# ==== System: Samuel Neural Checkers II ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Samuel Neural Checkers II
#
#
# ==== System: BOXES ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BOXES
#
#
# ==== System: GLEE ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for GLEE
#
#
# ==== System: Graph-based structural reasoning ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Graph-based structural reasoning
#
#
# ==== System: Punish/Reward ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Punish/Reward
#
#
# ==== System: Naive Bayes ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Naive Bayes
#
#
# ==== System: Cognitron ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Cognitron
#
#
# ==== System: Continuous speech recognition by statistical methods ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Continuous speech recognition by statistical methods
#
#
# ==== System: TD(0) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for TD(0)
#
#
# ==== System: Internal functionality of visual invariants ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Internal functionality of visual invariants
#
#
# ==== System: Neocognitron ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Neocognitron
#
#
# ==== System: Kohonen network ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Kohonen network
#
#
# ==== System: Hopfield network ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Hopfield network
#
#
# ==== System: ASE+ACE ====
# Could not find hardware model for ASE+ACE
#
#
# ==== System: Learnability theory of language development ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Learnability theory of language development
#
#
# ==== System: Error Propagation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Error Propagation
#
#
# ==== System: Learning past tenses ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Learning past tenses
#
#
# ==== System: PDP model for serial order ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for PDP model for serial order
#
#
# ==== System: Back-propagation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Back-propagation
#
#
# ==== System: Optimized Multi-Scale Edge Detection ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Optimized Multi-Scale Edge Detection
#
#
# ==== System: NetTalk (dictionary) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for NetTalk (dictionary)
#
#
# ==== System: NetTalk (transcription) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for NetTalk (transcription)
#
#
# ==== System: Motion-Driven 3D Feature Tracking ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Motion-Driven 3D Feature Tracking
#
#
# ==== System: Adaptive Broom Balancer ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Adaptive Broom Balancer
#
#
# ==== System: MADALINE II ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for MADALINE II
#
#
# ==== System: Q-learning ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Q-learning
#
#
# ==== System: Innervator ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Innervator
#
#
# ==== System: Time-delay neural networks ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Time-delay neural networks
#
#
# ==== System: Universal approximation via Feedforward Networks ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Universal approximation via Feedforward Networks
#
#
# ==== System: Invariant image recognition ====
# Could not find hardware model for Invariant image recognition
#
#
# ==== System: ALVINN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ALVINN
#
#
# ==== System: Zip CNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Zip CNN
#
#
# ==== System: MADALINE III ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for MADALINE III
#
#
# ==== System: MLP as Bayesian Approximator ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for MLP as Bayesian Approximator
#
#
# ==== System: DIABETES ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DIABETES
#
#
# ==== System: SRN-Encoded Grammatical Structures ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SRN-Encoded Grammatical Structures
#
#
# ==== System: TD-Gammon ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for TD-Gammon
#
#
# ==== System: REINFORCE in Stochastic Connectionism ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for REINFORCE in Stochastic Connectionism
#
#
# ==== System: Fuzzy NN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Fuzzy NN
#
#
# ==== System: IBM-5 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for IBM-5
#
#
# ==== System: Markov-driven POS tagger ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Markov-driven POS tagger
#
#
# ==== System: GroupLens ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for GroupLens
#
#
# ==== System: Multi-cause Binary Clustering ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Multi-cause Binary Clustering
#
#
# ==== System: Iterative Bootstrapping WSD ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Iterative Bootstrapping WSD
#
#
# ==== System: Random Decision Forests ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Random Decision Forests
#
#
# ==== System: Support Vector Machines ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Support Vector Machines
#
#
# ==== System: System 11 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for System 11
#
#
# ==== System: HMM Word Alignment ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for HMM Word Alignment
#
#
# ==== System: Deep Blue ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Deep Blue
#
#
# ==== System: SVM for face detection ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SVM for face detection
#
#
# ==== System: n-gram LM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for n-gram LM
#
#
# ==== System: Bidirectional RNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Bidirectional RNN
#
#
# ==== System: LSTM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LSTM
#
#
# ==== System: Sparse coding model for V1 receptive fields ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Sparse coding model for V1 receptive fields
#
#
# ==== System: RNN for speech ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RNN for speech
#
#
# ==== System: Probabilistic modeling for object recognition ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Probabilistic modeling for object recognition
#
#
# ==== System: Social and content-based classification ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Social and content-based classification
#
#
# ==== System: LeNet-5 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LeNet-5
#
#
# ==== System: LSTM with forget gates ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LSTM with forget gates
#
#
# ==== System: Credibilty Network ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Credibilty Network
#
#
# ==== System: IBM Model 4 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for IBM Model 4
#
#
# ==== System: Perceptron for Large Margin Classification ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Perceptron for Large Margin Classification
#
#
# ==== System: SVD in recommender systems ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SVD in recommender systems
#
#
# ==== System: Peephole LSTM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Peephole LSTM
#
#
# ==== System: FrameNet role labeling ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for FrameNet role labeling
#
#
# ==== System: Immediate trihead ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Immediate trihead
#
#
# ==== System: Gradient Boosting Machine ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Gradient Boosting Machine
#
#
# ==== System: Decision tree (classification) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Decision tree (classification)
#
#
# ==== System: Thumbs Up? ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Thumbs Up?
#
#
# ==== System: Joint Probability Machine Translation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Joint Probability Machine Translation
#
#
# ==== System: NEAT in neuroevolution ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for NEAT in neuroevolution
#
#
# ==== System: Tagging via Viterbi Decoding ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Tagging via Viterbi Decoding
#
#
# ==== System: Maximum Entropy Models for machine translation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Maximum Entropy Models for machine translation
#
#
# ==== System: Web mining + Decision tree recommender ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Web mining + Decision tree recommender
#
#
# ==== System: Statistical Shape Constellations ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Statistical Shape Constellations
#
#
# ==== System: LDA ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LDA
#
#
# ==== System: NPLM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for NPLM
#
#
# ==== System: Phrase-based translation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Phrase-based translation
#
#
# ==== System: Unsupervised Scale-Invariant Learning ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Unsupervised Scale-Invariant Learning
#
#
# ==== System: CNN Best Practices ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for CNN Best Practices
#
#
# ==== System: A Bayesian Approach to Unsupervised One-Shot Learning of Object Categories ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for A Bayesian Approach to Unsupervised One-Shot Learning of Object Categories
#
#
# ==== System: Max-Margin Markov Networks ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Max-Margin Markov Networks
#
#
# ==== System: GPU implementation of neural networks ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for GPU implementation of neural networks
#
#
# ==== System: Sandstorm (DARPA Grand Challenge I) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Sandstorm (DARPA Grand Challenge I)
#
#
# ==== System: Automated WSD via WordNet ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Automated WSD via WordNet
#
#
# ==== System: LIRA ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LIRA
#
#
# ==== System: SACHS ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SACHS
#
#
# ==== System: Hiero ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Hiero
#
#
# ==== System: ConvNet similarity metric ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ConvNet similarity metric
#
#
# ==== System: Histograms of Oriented Gradients ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Histograms of Oriented Gradients
#
#
# ==== System: BiLSTM for Speech ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BiLSTM for Speech
#
#
# ==== System: Stanley (DARPA Grand Challenge 2) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Stanley (DARPA Grand Challenge 2)
#
#
# ==== System: TFE SVM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for TFE SVM
#
#
# ==== System: RL for helicopter flight ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RL for helicopter flight
#
#
# ==== System: FAST ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for FAST
#
#
# ==== System: Spatial Pyramid Matching ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Spatial Pyramid Matching
#
#
# ==== System: DrLIM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DrLIM
#
#
# ==== System: CTC-Trained LSTM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for CTC-Trained LSTM
#
#
# ==== System: Semantic Taxonomy Induction ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Semantic Taxonomy Induction
#
#
# ==== System: DImensionality Reduction ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DImensionality Reduction
#
#
# ==== System: Deep Belief Nets ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Deep Belief Nets
#
#
# ==== System: Local Binary Patterns for facial recognition ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Local Binary Patterns for facial recognition
#
#
# ==== System: Greedy layer-wise DNN training ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Greedy layer-wise DNN training
#
#
# ==== System: Sparse Energy-Based Model ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Sparse Energy-Based Model
#
#
# ==== System: Empirical evaluation of deep architectures ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Empirical evaluation of deep architectures
#
#
# ==== System: Restricted Bolzmann machines ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Restricted Bolzmann machines
#
#
# ==== System: Regularized SVD for Collaborative Filtering ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Regularized SVD for Collaborative Filtering
#
#
# ==== System: BLSTM for handwriting (1) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BLSTM for handwriting (1)
#
#
# ==== System: Enhanced Neighborhood-Based Filtering ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Enhanced Neighborhood-Based Filtering
#
#
# ==== System: BLSTM for handwriting (2) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BLSTM for handwriting (2)
#
#
# ==== System: Multiscale deformable part model ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Multiscale deformable part model
#
#
# ==== System: Deep Multitask NLP Network ====
# Could not find hardware model for Deep Multitask NLP Network
#
#
# ==== System: Semi-Supervised Embedding for DL ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Semi-Supervised Embedding for DL
#
#
# ==== System: Denoising Autoencoders ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Denoising Autoencoders
#
#
# ==== System: Stacked Semisuperviser Autoencoders ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Stacked Semisuperviser Autoencoders
#
#
# ==== System: Boss (DARPA Urban Challenge) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Boss (DARPA Urban Challenge)
#
#
# ==== System: Sparse digit recognition SVM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Sparse digit recognition SVM
#
#
# ==== System: BigChaos 2008 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BigChaos 2008
#
#
# ==== System: Semantic Hashing ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Semantic Hashing
#
#
# ==== System: RBM Image Classifier ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RBM Image Classifier
#
#
# ==== System: Deep Boltzmann Machines ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Deep Boltzmann Machines
#
#
# ==== System: Conv-DBN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Conv-DBN
#
#
# ==== System: GPU DBNs ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for GPU DBNs
#
#
# ==== System: Pragmatic Theory solution (Netflix 2009) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Pragmatic Theory solution (Netflix 2009)
#
#
# ==== System: BellKor 2009 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BellKor 2009
#
#
# ==== System: BigChaos OptiBlend ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BigChaos OptiBlend
#
#
# ==== System: BellKor 2008 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BellKor 2008
#
#
# ==== System: RL mapping instructions (games) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RL mapping instructions (games)
#
#
# ==== System: RL mapping instructions (troubleshooting) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RL mapping instructions (troubleshooting)
#
#
# ==== System: MatrixFac for Recommenders ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for MatrixFac for Recommenders
#
#
# ==== System: Polarity Classifier ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Polarity Classifier
#
#
# ==== System: BellKor 2007 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BellKor 2007
#
#
# ==== System: 3D city reconstruction ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for 3D city reconstruction
#
#
# ==== System: Learning deep architectures ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Learning deep architectures
#
#
# ==== System: Super-vector coding ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Super-vector coding
#
#
# ==== System: Stacked Denoising Autoencoders ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Stacked Denoising Autoencoders
#
#
# ==== System: 6-layer MLP (MNIST) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for 6-layer MLP (MNIST)
#
#
# ==== System: Feedforward NN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Feedforward NN
#
#
# ==== System: Word Representations ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Word Representations
#
#
# ==== System: Mid-level Features ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Mid-level Features
#
#
# ==== System: Deconvolutional Network ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Deconvolutional Network
#
#
# ==== System: ReLU (LFW) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ReLU (LFW)
#
#
# ==== System: ReLU (NORB) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ReLU (NORB)
#
#
# ==== System: RBM-tuning ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RBM-tuning
#
#
# ==== System: Fisher-Boost ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Fisher-Boost
#
#
# ==== System: YouTube Video Recommendation System ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for YouTube Video Recommendation System
#
#
# ==== System: RNN 500/10 + RT09 LM (NIST RT05) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RNN 500/10 + RT09 LM (NIST RT05)
#
#
# ==== System: KN5 LM + RNN 400/10 (WSJ) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for KN5 LM + RNN 400/10 (WSJ)
#
#
# ==== System: Culturome ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Culturome
#
#
# ==== System: Optimized Single-layer Net ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Optimized Single-layer Net
#
#
# ==== System: Deep rectifier networks ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Deep rectifier networks
#
#
# ==== System: RNN-SpeedUp ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RNN-SpeedUp
#
#
# ==== System: Cross-Lingual POS Tagger ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Cross-Lingual POS Tagger
#
#
# ==== System: Recursive sentiment autoencoder ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Recursive sentiment autoencoder
#
#
# ==== System: Bayesian Starcraft ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Bayesian Starcraft
#
#
# ==== System: Adaptive Subgrad ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Adaptive Subgrad
#
#
# ==== System: Domain Adaptation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Domain Adaptation
#
#
# ==== System: NLP from scratch ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for NLP from scratch
#
#
# ==== System: HOGWILD! ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for HOGWILD!
#
#
# ==== System: MCDNN (MNIST) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for MCDNN (MNIST)
#
#
# ==== System: LBL ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LBL
#
#
# ==== System: Ngram corpus ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Ngram corpus
#
#
# ==== System: MV-RNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for MV-RNN
#
#
# ==== System: Unsupervised High-level Feature Learner ====
# Could not find hardware model for Unsupervised High-level Feature Learner
#
#
# ==== System: Context-dependent RNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Context-dependent RNN
#
#
# ==== System: LSTM-300units ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LSTM-300units
#
#
# ==== System: RNN+LDA+KN5+cache ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RNN+LDA+KN5+cache
#
#
# ==== System: Bayesian automated hyperparameter tuning ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Bayesian automated hyperparameter tuning
#
#
# ==== System: RNN (SGD+CLR) (PTB) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RNN (SGD+CLR) (PTB)
#
#
# ==== System: RNN (SGD+CLR) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RNN (SGD+CLR)
#
#
# ==== System: Textual Imager ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Textual Imager
#
#
# ==== System: Maxout Networks ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Maxout Networks
#
#
# ==== System: PreTrans-3L-250H ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for PreTrans-3L-250H
#
#
# ==== System: SearchFusion ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SearchFusion
#
#
# ==== System: SemVec ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SemVec
#
#
# ==== System: Image Classification with the Fisher Vector: Theory and Practice ====
# Could not find hardware model for Image Classification with the Fisher Vector: Theory and Practice
#
#
# ==== System: RNN+weight noise+dynamic eval ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RNN+weight noise+dynamic eval
#
#
# ==== System: Mitosis ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Mitosis
#
#
# ==== System: Word2Vec (large) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Word2Vec (large)
#
#
# ==== System: Word2Vec (small) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Word2Vec (small)
#
#
# ==== System: R-CNN (T-net) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for R-CNN (T-net)
#
#
# ==== System: TensorReasoner ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for TensorReasoner
#
#
# ==== System: TransE ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for TransE
#
#
# ==== System: DBLSTM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DBLSTM
#
#
# ==== System: RNN for 1B words ====
# Could not find hardware model for RNN for 1B words
#
#
# ==== System: Network in Network ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Network in Network
#
#
# ==== System: DQN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DQN
#
#
# ==== System: Image generation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Image generation
#
#
# ==== System: DOT(S)-RNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DOT(S)-RNN
#
#
# ==== System: OverFeat ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for OverFeat
#
#
# ==== System: SPN-4+KN5 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SPN-4+KN5
#
#
# ==== System: GloVe (32B) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for GloVe (32B)
#
#
# ==== System: GloVe (6B) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for GloVe (6B)
#
#
# ==== System: DBN for NLP ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DBN for NLP
#
#
# ==== System: HyperNEAT ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for HyperNEAT
#
#
# ==== System: Dropout: SVHN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Dropout: SVHN
#
#
# ==== System: GRUs ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for GRUs
#
#
# ==== System: Two-stream ConvNets for action recognition ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Two-stream ConvNets for action recognition
#
#
# ==== System: GANs ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for GANs
#
#
# ==== System: RNN-WER ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RNN-WER
#
#
# ==== System: DeepFace ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DeepFace
#
#
# ==== System: Multiresolution CNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Multiresolution CNN
#
#
# ==== System: SmooCT ====
# Could not find hardware model for SmooCT
#
#
# ==== System: AdClickNet ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for AdClickNet
#
#
# ==== System: RNNsearch-50* ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RNNsearch-50*
#
#
# ==== System: VGG19 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for VGG19
#
#
# ==== System: Large regularized LSTM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Large regularized LSTM
#
#
# ==== System: Seq2Seq LSTM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Seq2Seq LSTM
#
#
# ==== System: Deeply-supervised nets ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Deeply-supervised nets
#
#
# ==== System: Spatially-Sparse CNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Spatially-Sparse CNN
#
#
# ==== System: LRCN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LRCN
#
#
# ==== System: Fully Convolutional Networks ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Fully Convolutional Networks
#
#
# ==== System: Cascaded LNet-ANet ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Cascaded LNet-ANet
#
#
# ==== System: Sparse Non-negative Matrix (SNM) estimation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Sparse Non-negative Matrix (SNM) estimation
#
#
# ==== System: NTM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for NTM
#
#
# ==== System: ADAM (CIFAR-10) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ADAM (CIFAR-10)
#
#
# ==== System: 4-gram + 8 DENN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for 4-gram + 8 DENN
#
#
# ==== System: DeepLab ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DeepLab
#
#
# ==== System: SCRN(Structurally Constrained Recurrent Network) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SCRN(Structurally Constrained Recurrent Network)
#
#
# ==== System: MSRA (C, PReLU) ====
# Could not find hardware model for MSRA (C, PReLU)
#
#
# ==== System: CRF-RNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for CRF-RNN
#
#
# ==== System: DQN-2015 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DQN-2015
#
#
# ==== System: Constituency-Tree LSTM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Constituency-Tree LSTM
#
#
# ==== System: Stack RNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Stack RNN
#
#
# ==== System: genCNN + dyn eval ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for genCNN + dyn eval
#
#
# ==== System: Fast R-CNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Fast R-CNN
#
#
# ==== System: Deep LSTM for video classification ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Deep LSTM for video classification
#
#
# ==== System: 2nd order FOFE-FNNLM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for 2nd order FOFE-FNNLM
#
#
# ==== System: Trajectory-pooled conv nets ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Trajectory-pooled conv nets
#
#
# ==== System: Draw ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Draw
#
#
# ==== System: Faster R-CNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Faster R-CNN
#
#
# ==== System: GoogLeNet / InceptionV1 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for GoogLeNet / InceptionV1
#
#
# ==== System: YOLO ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for YOLO
#
#
# ==== System: BatchNorm ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BatchNorm
#
#
# ==== System: Skip-Thoughts ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Skip-Thoughts
#
#
# ==== System: Search-Proven Best LSTM ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Search-Proven Best LSTM
#
#
# ==== System: Listen, Attend and Spell ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Listen, Attend and Spell
#
#
# ==== System: LSTM-Char-Large ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for LSTM-Char-Large
#
#
# ==== System: BPE ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BPE
#
#
# ==== System: Deep Deterministic Policy Gradients ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Deep Deterministic Policy Gradients
#
#
# ==== System: AlphaGo Fan ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for AlphaGo Fan
#
#
# ==== System: The Attentive Reader ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for The Attentive Reader
#
#
# ==== System: Multi-scale Dilated CNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Multi-scale Dilated CNN
#
#
# ==== System: Netflix Recommender System ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Netflix Recommender System
#
#
# ==== System: Inception v3 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Inception v3
#
#
# ==== System: DeepSpeech2 (English) ====
# Trying NVIDIA GTX Titan X at 2015-09-04 00:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: ResNet-110 (CIFAR-10) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ResNet-110 (CIFAR-10)
#
#
# ==== System: ResNet-152 (ImageNet) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ResNet-152 (ImageNet)
#
#
# ==== System: BPL ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for BPL
#
#
# ==== System: Advantage Learning ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Advantage Learning
#
#
# ==== System: Variational (untied weights, MC) LSTM (Large) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Variational (untied weights, MC) LSTM (Large)
#
#
# ==== System: AlphaGo Lee ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for AlphaGo Lee
#
#
# ==== System: Convolutional Pose Machines ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Convolutional Pose Machines
#
#
# ==== System: A3C FF hs ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for A3C FF hs
#
#
# ==== System: Inception-ResNet-V2 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Inception-ResNet-V2
#
#
# ==== System: Inceptionv4 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Inceptionv4
#
#
# ==== System: SqueezeNet ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SqueezeNet
#
#
# ==== System: Order-Embeddings of Images and Language ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Order-Embeddings of Images and Language
#
#
# ==== System: Binarized Neural Network (MNIST) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Binarized Neural Network (MNIST)
#
#
# ==== System: Symmetric Residual Encoder-Decoder Net ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Symmetric Residual Encoder-Decoder Net
#
#
# ==== System: Gated HORNN (3rd order) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Gated HORNN (3rd order)
#
#
# ==== System: Spatiotemporal fusion ConvNet ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Spatiotemporal fusion ConvNet
#
#
# ==== System: DMN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DMN
#
#
# ==== System: R-FCN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for R-FCN
#
#
# ==== System: Wide & Deep ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Wide & Deep
#
#
# ==== System: fastText ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for fastText
#
#
# ==== System: VD-RHN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for VD-RHN
#
#
# ==== System: Character-enriched word2vec ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Character-enriched word2vec
#
#
# ==== System: Layer Normalization: Order embeddings of images and language ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Layer Normalization: Order embeddings of images and language
#
#
# ==== System: Layer Normalization: The Attentive Reader ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Layer Normalization: The Attentive Reader
#
#
# ==== System: Layer Normalization: Draw ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Layer Normalization: Draw
#
#
# ==== System: Layer Normalization: Handwriting sequence generation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Layer Normalization: Handwriting sequence generation
#
#
# ==== System: Layer Normalization: Skip Thoughts ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Layer Normalization: Skip Thoughts
#
#
# ==== System: Attend-Infer-Repeat ====
# Trying NVIDIA Quadro K4000 at 2016-05-12 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: DenseNet-264 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for DenseNet-264
#
#
# ==== System: Multi-task Cascaded CNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Multi-task Cascaded CNN
#
#
# ==== System: WaveNet ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for WaveNet
#
#
# ==== System: Youtube recommendation model ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Youtube recommendation model
#
#
# ==== System: MS-CNN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for MS-CNN
#
#
# ==== System: Stacked hourglass network ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Stacked hourglass network
#
#
# ==== System: ResNet-1001 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ResNet-1001
#
#
# ==== System: ResNet-200 ====
# Could not find hardware model for ResNet-200
#
#
# ==== System: TSN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for TSN
#
#
# ==== System: Wide Residual Network ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Wide Residual Network
#
#
# ==== System: Byte-mLSTM+emb+WN+VD ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Byte-mLSTM+emb+WN+VD
#
#
# ==== System: Zoneout + Variational LSTM (WT2) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Zoneout + Variational LSTM (WT2)
#
#
# ==== System: Pointer Sentinel-LSTM (medium) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Pointer Sentinel-LSTM (medium)
#
#
# ==== System: GNMT ====
# Trying NVIDIA Tesla K80 at 2015-12-31 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 0.43 at 2017-02-10 00:00:00
# Difference between acquisition date and price date: -407 days +00:00:00
#
# ==== System: Xception ====
# Trying NVIDIA Tesla K80 at 2016-06-09 00:00:00
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Found price: 0.43 at 2017-02-10 00:00:00
# Difference between acquisition date and price date: -246 days +00:00:00
#
# ==== System: Differentiable neural computer ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Differentiable neural computer
#
#
# ==== System: SPIDER2 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for SPIDER2
#
#
# ==== System: VD-LSTM+REAL Large ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for VD-LSTM+REAL Large
#
#
# ==== System: Neural Architecture Search with base 8 and shared embeddings ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Neural Architecture Search with base 8 and shared embeddings
#
#
# ==== System: BIDAF ====
# Trying NVIDIA GTX Titan X at 2016-08-04 12:00:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: NASv3 (CIFAR-10) ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for NASv3 (CIFAR-10)
#
#
# ==== System: Deeply-recursive ConvNet ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Deeply-recursive ConvNet
#
#
# ==== System: ResNeXt-50 ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for ResNeXt-50
#
#
# ==== System: PolyNet ====
# No training time found, assuming 33.0625
#
# Trying NVIDIA GTX Titan X at 2016-07-16 22:30:00
# Trying Amazon Web Services, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (3-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (1-year CUD)
# Could not find price
#
# Trying Amazon Web Services, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Microsoft Azure, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Google Cloud, Price per chip-hour (on-demand)
# Could not find price
#
# Trying Lambda Labs, Price per chip-hour (on-demand)
# Could not find price
#
# ==== System: RefineNet ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for RefineNet
#
#
# ==== System: Image-to-image cGAN ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Image-to-image cGAN
#
#
# ==== System: Elastic weight consolidation ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for Elastic weight consolidation
#
#
# ==== System: PointNet ====
# No training time found, assuming 33.0625
#
# Could not find hardware model for PointNet
#
#
# ==== System: GAN-Advancer ====
# ...
# ==== System: PULI GPTrio ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 at 312000000000000.0 FLOP/s
# Estimated cost: 19966.7616334283
# ==== System: MathGPT ====
# Unable to estimate cost
# ==== System: Qwen-VL ====
# Unable to estimate cost
# ==== System: HyperCLOVA X ====
# Unable to estimate cost
# ==== System: Jais ====
# Unable to estimate cost
# ==== System: ABAB ====
# Unable to estimate cost
# ==== System: 360 Smart Brain ====
# Unable to estimate cost
# ==== System: Falcon-180B ====
# Estimated cost: 25657344.0
# ==== System: TigerBot-70B ====
# Unable to estimate cost
# ==== System: Baichuan2-13B ====
# Unable to estimate cost
# ==== System: Persimmon-8B ====
# Unable to estimate cost
# ==== System: XGen-7B ====
# Imputing training time from compute and hardware
# Found Google TPU v4 at 275000000000000.0 FLOP/s
# Estimated cost: 313239.0572390572
# ==== System: Mobile V-MoEs ====
# Unable to estimate cost
# ==== System: MADLAD-400 10B ====
# Unable to estimate cost
# ==== System: Phi-1.5 ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 SXM4 40 GB at 312000000000000.0 FLOP/s
# Estimated cost: 3777.7777777777783
# ==== System: DeciLM 6B ====
# Unable to estimate cost
# ==== System: bge-reranker-large ====
# Unable to estimate cost
# ==== System: AlphaMissense ====
# Unable to estimate cost
# ==== System: GPT-4V ====
# Unable to estimate cost
# ==== System: InternLM-XComposer ====
# Estimated cost: 14848.0
# ==== System: Emu (Meta) ====
# Unable to estimate cost
# ==== System: Show-1 ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: PLaMo-13B ====
# Unable to estimate cost
# ==== System: Amazon Titan ====
# Unable to estimate cost
# ==== System: StableLM-3B-4E1T ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 at 312000000000000.0 FLOP/s
# Estimated cost: 213782.05128205128
# ==== System: CTM (CIFAR-10) ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: TinyLlama-1.1B (3T token checkpoint) ====
# Estimated cost: 50112.0
# ==== System: LLaMA-7B (protein-oriented instructions finetuned) ====
# Unable to estimate cost
# ==== System: RoseTTAFold All-Atom (RFAA) ====
# Unable to estimate cost
# ==== System: CodeFuse-13B ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 SXM4 80 GB at 312000000000000.0 FLOP/s
# Estimated cost: 1418091.1680911682
# ==== System: Mistral 7B ====
# Unable to estimate cost
# ==== System: Ferret (13B) ====
# Base model found, but unable to estimate cost
# Unable to estimate cost
# ==== System: Jiutian ====
# Unable to estimate cost
# ==== System: Aquila2 34B ====
# Unable to estimate cost
# ==== System: Table-GPT ====
# Unable to estimate cost
# ==== System: RT-2-X ====
# Unable to estimate cost
# ==== System: Fuyu-8B ====
# Unable to estimate cost
# ==== System: ERNIE 4.0 ====
# Unable to estimate cost
# ==== System: KwaiYiiMath ====
# Unable to estimate cost
# ==== System: DALL·E 3 ====
# Unable to estimate cost
# ==== System: Stockmark-13B ====
# Unable to estimate cost
# ==== System: Spark 3.0 ====
# Unable to estimate cost
# ==== System: Xinghan Foundation Model ====
# Unable to estimate cost
# ==== System: QMoE: compressed 1T model ====
# Unable to estimate cost
# ==== System: CODEFUSION (Python) ====
# Unable to estimate cost
# ==== System: DiT-XL/2 + CADS ====
# Unable to estimate cost
# ==== System: ChatGLM3 ====
# Unable to estimate cost
# ==== System: Tongyi Qianwen (Qwen) 2.0 ====
# Unable to estimate cost
# ==== System: OpenChat 3.5-7B ====
# Unable to estimate cost
# ==== System: Calm2-7B ====
# Unable to estimate cost
# ==== System: LingoWhale-8B ====
# Unable to estimate cost
# ==== System: Nanbeige-16B ====
# Unable to estimate cost
# ==== System: DeepSeek Coder 33B ====
# Unable to estimate cost
# ==== System: Cohere Embed ====
# Unable to estimate cost
# ==== System: Yi-34B ====
# Unable to estimate cost
# ==== System: RT-Trajectory ====
# Unable to estimate cost
# ==== System: Grok-0 ====
# Unable to estimate cost
# ==== System: Grok-1 ====
# Unable to estimate cost
# ==== System: LLaVA 1.5 ====
# Base model found, but unable to estimate cost
# Unable to estimate cost
# ==== System: Consistency Decoder ====
# Unable to estimate cost
# ==== System: XVERSE-13B-2 ====
# Unable to estimate cost
# ==== System: CogVLM ====
# Unable to estimate cost
# ==== System: GPT-4 Turbo ====
# Unable to estimate cost
# ==== System: Whisper v3 ====
# Unable to estimate cost
# ==== System: OtterHD-8B ====
# Base model found, but unable to estimate cost
# Unable to estimate cost
# ==== System: mPLUG-Owl2 ====
# Unable to estimate cost
# ==== System: OmniVec ====
# Unable to estimate cost
# ==== System: Prithvi-100M ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 at 312000000000000.0 FLOP/s
# Estimated cost: 7914.872341880343
# ==== System: Samsung Gauss Language ====
# Unable to estimate cost
# ==== System: MultiBand Diffusion ====
# Imputing training time from compute and hardware
# Found NVIDIA V100 at 125000000000000.0 FLOP/s
# Estimated cost: 189.51111111111112
# ==== System: SPHINX (Llama 2 13B) ====
# Base model specified, but not found in database
# Unable to estimate cost
# ==== System: Volcano 13B ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: LLaVA + LVIS-INSTRUCT4V ====
# Unable to estimate cost
# ==== System: Qwen-Audio-Chat ====
# Unable to estimate cost
# ==== System: GraphCast ====
# Unable to estimate cost
# ==== System: Nemotron-3-8B ====
# Estimated cost: 677068.7999999999
# ==== System: Mistral 7B + OVM ====
# Unable to estimate cost
# ==== System: Lyria ====
# Unable to estimate cost
# ==== System: Orca 2-13B ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 SXM4 80 GB at 312000000000000.0 FLOP/s
# Base model specified, but not found in database
# Unable to estimate cost
# ==== System: Claude 2.1 ====
# Unable to estimate cost
# ==== System: Inflection-2 ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 SXM5 at 989000000000000.0 FLOP/s
# Estimated cost: 11512830.768078491
# ==== System: Starling-LM-7B-alpha ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: Yuan 2.0 ====
# Unable to estimate cost
# ==== System: StripedHyena-Hessian-7B ====
# Unable to estimate cost
# ==== System: PPLX-70B-Online ====
# Unable to estimate cost
# ==== System: GNoME for crystal discovery ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: Cohere Command Light ====
# Imputing training time from compute and hardware
# Found Google TPU v4 at 275000000000000.0 FLOP/s
# Estimated cost: 39096.29629629629
# ==== System: Granite 13B ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 at 312000000000000.0 FLOP/s
# Estimated cost: 839981.0066476732
# ==== System: Qwen-72B ====
# Unable to estimate cost
# ==== System: Mamba-24M (SC09) ====
# Unable to estimate cost
# ==== System: NASA SMD ====
# Unable to estimate cost
# ==== System: tsuzumi 7B ====
# Unable to estimate cost
# ==== System: Mamba-2.8B ====
# Unable to estimate cost
# ==== System: SARA-RT-2 ====
# Unable to estimate cost
# ==== System: Gemini Ultra ====
# Estimated cost: 191400000.0
# ==== System: OneLLM ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: Gemini 1 Pro ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: Llama Guard ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: SeamlessM4T ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: XVERSE-65B-2 ====
# Unable to estimate cost
# ==== System: ruDalle: Kandinsky 3.1 ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: Mistral Medium ====
# Unable to estimate cost
# ==== System: Mixtral 8x7B ====
# Unable to estimate cost
# ==== System: Phi-2 ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 at 312000000000000.0 FLOP/s
# Estimated cost: 73295.34662867997
# ==== System: Imagen 2 ====
# Unable to estimate cost
# ==== System: FunSearch ====
# Unable to estimate cost
# ==== System: CogAgent ====
# Unable to estimate cost
# ==== System: Lyra-Fr 10B ====
# Unable to estimate cost
# ==== System: VideoPoet ====
# Unable to estimate cost
# ==== System: Solar-10.7B ====
# Unable to estimate cost
# ==== System: CoRe ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: Qarasu-14B ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: RT-1 + AutoRT ====
# Unable to estimate cost
# ==== System: DeepSeek LLM 67B ====
# Unable to estimate cost
# ==== System: Stable Code 3B ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 SXM4 40 GB at 312000000000000.0 FLOP/s
# Estimated cost: 72500.0
# ==== System: MAGNeT ====
# Unable to estimate cost
# ==== System: DeepSeekMoE-16B ====
# Unable to estimate cost
# ==== System: InternLM2-20b ====
# Unable to estimate cost
# ==== System: DeciCoder-6B ====
# Unable to estimate cost
# ==== System: AlphaGeometry ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: StableLM-2-1.6B ====
# Imputing training time from compute and hardware
# Found NVIDIA A100 SXM4 40 GB at 312000000000000.0 FLOP/s
# Estimated cost: 66096.8660968661
# ==== System: Lumiere ====
# Unable to estimate cost
# ==== System: Fuyu-Heavy ====
# Unable to estimate cost
# ==== System: Qwen-VL-Max ====
# Unable to estimate cost
# ==== System: Karakuri LM ====
# Unable to estimate cost
# ==== System: Code Llama-70B ====
# Estimated cost: 7819200.0
# ==== System: LLaVA-NeXT-34B (LLaVA-1.6) ====
# Estimated cost: 1113.6
# ==== System: OLMo-7B ====
# Unable to estimate cost
# ==== System: Qwen1.5 72B ====
# Unable to estimate cost
# ==== System: Distilled Grandmaster ====
# Unable to estimate cost
# ==== System: Aya ====
# Unable to estimate chip hours
# Unable to estimate cost
# ==== System: Gemini 1.5 Pro ====
# Unable to estimate cost
# ==== System: Sora ====
# Unable to estimate cost
# ==== System: Stable Diffusion 3 ====
# Unable to estimate cost
# ==== System: MegaScale (Production) ====
# Estimated cost: 8980070.4
# ==== System: Mistral Large ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 PCIe at 756000000000000.0 FLOP/s
# Estimated cost: 21469723.693019398
# ==== System: Evo ====
# Unable to estimate cost
# ==== System: Hawk ====
# Imputing training time from compute and hardware
# Found Google TPU v3 at 123000000000000.0 FLOP/s
# Estimated cost: 19884.010840108403
# ==== System: Griffin ====
# Imputing training time from compute and hardware
# Found Google TPU v3 at 123000000000000.0 FLOP/s
# Estimated cost: 85902.07005209288
# ==== System: StarCoder 2 15B ====
# Unable to estimate cost
# ==== System: Humanoid Locomotion ====
# Unable to estimate cost
# ==== System: Claude 3 Opus ====
# Unable to estimate cost
# ==== System: GroundingGPT ====
# Unable to estimate cost
# ==== System: Inflection-2.5 ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 SXM5 at 989000000000000.0 FLOP/s
# Estimated cost: 11502479.571583716
# ==== System: MM1-30B ====
# Unable to estimate cost
# ==== System: DBRX ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 SXM5 at 989000000000000.0 FLOP/s
# Estimated cost: 2990345.6540463613
# ==== System: Grok-1.5 ====
# Unable to estimate cost
# ==== System: Grok-1.5V ====
# Unable to estimate cost
# ==== System: Voice Engine ====
# Unable to estimate cost
# ==== System: ReALM ====
# Unable to estimate cost
# ==== System: POKE´LLMON ====
# Unable to estimate cost
# ==== System: Mixture-of-Depths ====
# Unable to estimate cost
# ==== System: Command R+ ====
# Unable to estimate cost
# ==== System: Stable LM 2 12B ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 SXM5 at 989000000000000.0 FLOP/s
# Estimated cost: 334688.6866644197
# ==== System: Reka Core ====
# Unable to estimate cost
# ==== System: Mixtral 8x22B ====
# Unable to estimate cost
# ==== System: SIMA ====
# Unable to estimate cost
# ==== System: FRED-T5-XL ====
# Unable to estimate cost
# ==== System: Llama 3-70B ====
# Imputing training time from compute and hardware
# Found NVIDIA H100 SXM5 at 989000000000000.0 FLOP/s
# Estimated cost: 6792972.699707445
# ==== System: SenseNova 5.0 ====
# Unable to estimate cost
# ==== System:  phi-3-medium 14B ====
# Unable to estimate cost
# ==== System: Qwen 1.5 110B ====
# Unable to estimate cost
# ==== System: Fugaku-LLM ====
# Unable to estimate cost
# All costs:
# {'GNMT': 178329.6, 'Xception': 18576.0, 'Transformer': 618.24, 'JFT': 30960.0, 'AlphaZero': 300196.45329923165, 'IMPALA': 92.0, 'LSTM (Hebbian, Cache, MbPA)': 1059.8400000000001, 'RNMT+': 3532.8, 'QT-Opt': 2555.5555555555557, 'Big Transformer for Back-Translation': 4355.73504, 'Transformer + Simple Recurrent Unit': 80.17777777777776, 'Transformer (Adaptive Input Embeddings)': 659.28, 'BigGAN-deep 512x512': 10813.439999999999, 'BERT-Large': 3054.7967999999996, 'Mesh-TensorFlow Transformer 2.9B (translation)': 700.0575999999999, 'Mesh-TensorFlow Transformer 4.9B (language modelling)': 1654.6815999999997, 'ProxylessNAS': 270.16704000000004, 'KataGo': 169.1022222222222, 'UniRep': 1011.36, 'SciBERT': 591.3599999999999, 'MnasNet-A1 + SSDLite': 24330.239999999998, 'MnasNet-A3': 24330.239999999998, 'TAPE Transformer': 826.56, 'RoBERTa Large': 148684.8, 'Megatron-BERT': 876625.92, 'Megatron-LM (8.3B)': 202583.04, "Rubik's cube ADR robot": 5870.459259259259, 'T5-11B': 222059.52, 'T5-3B': 4588.7477148375065, 'AlphaStar': 356843.51999999996, 'CamemBERT': 6049.777777777778, 'Noisy Student (L2)': 132710.4, 'DD-PPO': 5195.5199999999995, 'ContextNet + Noisy Student': 29268.29268292683, 'Meena': 663552.0, 'ALBERT-xxlarge': 14745.6, 'Turing-NLG': 107922.96296296295, 'Cube-Space AutoEncoder': 10.32, 'Once for All': 13005.425663999999, 'ATLAS': 207.36, 'DETR': 2915.5555555555557, 'GPT-3 175B (davinci)': 4120319.9999999995, 'iGPT-XL': 226844.44444444444, 'iGPT-L': 61247.99999999999, 'GShard (dense)': 928972.8, 'mBART-50': 132249.6, 'ESM1-670M (UR50/D)': 3498.6666666666665, 'ProBERTa': 70.848, 'LUKE': 14169.6, 'Conformer + Wav2vec 2.0 + Noisy Student': 38707.200000000004, 'GBERT-Large': 15206.4, 'German ELECTRA Large': 9676.800000000001, 'ViT-Huge/14': 27070.630081300813, 'wave2vec 2.0 LARGE': 13623.703703703703, 'AlphaFold 2': 16205.962059620597, 'CPM-Large': 26449.92, 'CLIP (ViT L/14@336px)': 85524.48, 'DALL-E': 323081.48148148146, 'Switch': 597196.8, 'DeiT': 1.4442496, 'MSA Transformer': 39365.33333333333, 'Meta Pseudo Labels': 243302.4, 'ProteinGAN': 193.20000000000002, 'M6-T': 39437.03703703704, 'ResNet-RS': 95573.33333333333, 'PLUG': 155904.0, 'ViT + DINO': 1530.6666666666665, 'ProtBERT-BFD': 211382.11382113822, 'ProtT5-XXL-BFD': 200542.0054200542, 'ProtT5-XXL': 399457.9945799458, 'ADM': 3437.0370370370365, 'MedBERT': 203.28, 'ConSERT': 1962.3931623931626, 'CogView': 195342.22222222225, 'ByT5-XXL': 439024.39024390245, 'ViT-G/14': 18428.184281842816, 'EMDR': 3032.2886989553654, 'CoAtNet': 231436.3143631436, 'DeBERTa': 26726.399999999998, 'Denoising Diffusion Probabilistic Models (LSUN Bedroom)': 2059.620596205962, 'ALIGN': 160035.84, 'EfficientNetV2': 518.1571815718157, 'ERNIE 3.0': 164000.0, 'GOAT': 422764.22764227644, 'SEER': 118947.84, 'ProteinLM': 14878.08, 'FLAN 137B': 1279872.0, 'HyperCLOVA': 955023.36, 'MegaMolBART': 5248.0, 'AlphaFold-Multimer': 38324.3620596206, 'Megatron-Turing NLG 530B': 6209280.0, 'T0-XXL': 62208.0, 'DALL-E mini': 259.2, 'CodeT5-base': 5370.37037037037, 'Swin Transformer V2': 3551.756885090219, 'BASIC-L': 160915.82491582492, 'Florence': 167116.80000000002, 'CTR-BERT': 222.72, 'Gopher (280B)': 3391488.0, 'GLaM': 2028236.8, 'XGLM-7.5B': 187084.8, 'Fairseq-dense 13B': 112467.94871794872, 'MoE-1.1T': 76665.47958214625, 'Detic': 944.64, 'DARK': 70.70222222222222, 'GPT-NeoX-20B': 300672.0, 'LaMDA': 1276416.0, 'PaLM (540B)': 12187238.4, 'Stable Diffusion (LDM-KL-8-G)': 217500.0, 'Flamingo': 801792.0, 'OPT-175B': 1470704.6400000001, 'UL2': 552345.6, 'Gato': 22118.4, 'Imagen': 35635.2, 'Tranception': 31180.8, 'CoCa': 356352.0, 'Unified-IO': 13670.033670033668, 'Parti': 1547797.5206678305, 'YaLM': 1809600.0, 'GPT-SW3': 4475.308641975309, 'ProGen2-xlarge': 73170.73170731709, 'DALL-E mega': 154828.80000000002, 'Minerva (540B)': 13220659.200000001, 'CodeT5-large': 9363.72269705603, 'NLLB': 75249.664, 'Rita-XLarge': 24782.22222222222, 'ESM2-15B': 906854.4, 'OmegaPLM': 59310.08, 'ProtGPT2': 17817.6, 'AlexaTM 20B': 534528.0, 'GLM- ...

# %%
with open(f'{results_dir}/cost_estimation.out', 'w') as f:
    with redirect_stdout(f):
        cost_df = cost_estimation_function(frontier_pcd_df, hardware_df, price_df)

# %%
if estimation_method == 'hardware-capex-opex':
    frontier_pcd_df_copy = frontier_pcd_df.copy()
    with open(f'{results_dir}/component_cost_estimation.out', 'w') as f:
        with redirect_stdout(f):
            component_cost_df = cost_estimation_function(frontier_pcd_df_copy, hardware_df, price_df, separate_components=True)

# %%
cost_df
# Out:
#                                   System    Domain  \
# 1292                             Theseus  Robotics
# 1291                               SNARC  Robotics
# 1290                   Genetic algorithm     Other
# 1289              Self Organizing System     Other
# 1288  Sequence-based pattern recognition    Vision
# ...                                  ...       ...
# 4                            Llama 3-70B  Language
# 3                          SenseNova 5.0  Language
# 2                       phi-3-medium 14B  Language
# 1                          Qwen 1.5 110B  Language
# 0                             Fugaku-LLM  Language
#
#                                            Organization Publication date  \
# 1292                                  Bell Laboratories       1950-07-02
# 1291                                 Harvard University       1952-01-08
# 1290                       Institute for Advanced Study       1954-07-02
# 1289        Massachusetts Institute of Technology (MIT)       1955-03-01
# 1288        Massachusetts Institute of Technology (MIT)       1955-03-01
# ...                                                 ...              ...
# 4                                               Meta AI       2024-04-18
# 3                                             SenseTime       2024-04-23
# 2                                             Microsoft       2024-04-23
# 1                                               Alibaba       2024-04-25
# 0     Tohoku University,CyberAgent,Tokyo Institute o...       2024-05-10
#
#                                               Reference  \
# 1292                                       Mighty Mouse
# 1291  A Neural-Analogue Calculator Based upon a Prob...
# 1290            Numerical testing of evolution theories
# 1289  Generalization of pattern recognition in a sel...
# 1288           Pattern recognition and modern computers
# ...                                                 ...
# 4     Introducing Meta Llama 3: The most capable ope...
# 3                                                   NaN
# 2     Phi-3 Technical Report: A Highly Capable Langu...
# 1     Qwen1.5-110B: The First 100B+ Model of the Qwe...
# 0     Release of “Fugaku-LLM” – a large language mod...
#
#                                                    Link    Parameters  \
# 1292  https://www.technologyreview.com/2018/12/19/13...  4.000000e+01
# 1291  https://en.wikipedia.org/wiki/Stochastic_neura...  4.000000e+01
# 1290  https://link.springer.com/article/10.1007/BF01...           NaN
# 1289     https://dl.acm.org/doi/10.1145/1455292.1455309  2.250000e+02
# 1288     https://dl.acm.org/doi/10.1145/1455292.1455310           NaN
# ...                                                 ...           ...
# 4     https://ai.meta.com/blog/meta-llama-3/\n\nhttp...  7.000000e+10
# 3                       https://zhidx.com/p/421866.html           NaN
# 2                      https://arxiv.org/abs/2404.14219  1.400000e+10
# 1     https://qwenlm.github.io/blog/qwen1.5-110b/?re...  1.100000e+11
# 0     https://www.fujitsu.com/global/about/resources...  1.300000e+10
#
#                                        Parameters notes  \
# 1292  The learned part is the maze configuration. Th...
# 1291  The link below seems to suggest the SNARC had ...
# 1290                                                NaN
# 1289         Figure 4 contains the learnt weight matrix
# 1288                                                NaN
# ...                                                 ...
# 4                                                   NaN
# 3                                                   NaN
# 2                                                   14B
# 1                                                   NaN
# 0            "Fugaku-LLM has 13 billion parameters (2)"
#
#       Training compute (FLOP)  \
# 1292             4.000000e+01
# 1291                      NaN
# 1290                      NaN
# 1289                      NaN
# 1288                      NaN
# ...                       ...
# 4                6.300000e+24
# 3                         NaN
# 2                4.032000e+23
# 1                         NaN
# 0                2.964000e+22
#
#                                  Training compute notes  ... Base model  \
# 1292  The "training" consists on the mouse running a...  ...        NaN
# 1291                                                NaN  ...        NaN
# 1290                                                NaN  ...        NaN
# 1289                                                NaN  ...        NaN
# 1288                                                NaN  ...        NaN
# ...                                                 ...  ...        ...
# 4     direct calculation\n15000000000000 tokens*7000...  ...        NaN
# 3                                                   NaN  ...        NaN
# 2     counting operations: 6×4.8×10^12×14×10^9 ≈ 4.0...  ...        NaN
# 1                                                   NaN  ...        NaN
# 0     https://www.wolframalpha.com/input?i=6+FLOP+*+...  ...        NaN
#
#       Finetune compute notes Training cloud compute vendor Batch size notes  \
# 1292                     NaN                           NaN              NaN
# 1291                     NaN                           NaN              NaN
# 1290                     NaN                           NaN              NaN
# 1289                     NaN                           NaN              NaN
# 1288                     NaN                           NaN              NaN
# ...                      ...                           ...              ...
# 4                        NaN                           NaN              NaN
# 3                        NaN                           NaN              NaN
# 2                        NaN                           NaN              NaN
# 1                        NaN                           NaN              NaN
# 0                        NaN                           NaN              NaN
#
#      Finetune compute (FLOP) Training compute upper bound Archived links  \
# 1292                     NaN                          NaN            NaN
# 1291                     NaN                          NaN            NaN
# 1290                     NaN                          NaN            NaN
# 1289                     NaN                          NaN            NaN
# 1288                     NaN                          NaN            NaN
# ...                      ...                          ...            ...
# 4                        NaN                          NaN            NaN
# 3                        NaN                          NaN            NaN
# 2                        NaN                          NaN            NaN
# 1                        NaN                          NaN            NaN
# 0                        NaN                          NaN            NaN
#
#      Benchmark data Decimal year          Cost
# 1292            NaN  1950.502740           NaN
# 1291            NaN  1952.019178           NaN
# 1290            NaN  1954.502740           NaN
# 1289            NaN  1955.166667           NaN
# 1288            NaN  1955.166667           NaN
# ...             ...          ...           ...
# 4               NaN  2024.296575  6.792973e+06
# 3               NaN  2024.310274           NaN
# 2               NaN  2024.310274           NaN
# 1               NaN  2024.315753           NaN
# 0               NaN  2024.357991           NaN
#
# [1238 rows x 47 columns]

# %%
cost_df['Cost'].notna().sum()
# Out:
# 220

# %% [markdown]
# Exclusion

# %%
for kw in exclude_models_containing:
    cost_df = cost_df[cost_df['System'].str.contains(kw) == False]
list(cost_df['System'])
# Out:
# ['Theseus',
#  'SNARC',
#  'Genetic algorithm',
#  'Self Organizing System',
#  'Sequence-based pattern recognition',
#  'Conditional probability machines',
#  'Perceptron Mark I',
#  'Pandemonium (morse)',
#  'Samuel Neural Checkers',
#  'Pattern recognition and reading by machine',
#  'Perceptron (1960)',
#  'ADALINE',
#  'LMS',
#  'Heuristic problem solving for AI',
#  'PAPA',
#  'Linear Decision Functions',
#  'MADALINE I',
#  'Print Recognition Logic',
#  'STeLLA',
#  'MENACE',
#  'Heuristic Reinforcement Learning',
#  'Samuel Neural Checkers II',
#  'BOXES',
#  'GLEE',
#  'Graph-based structural reasoning',
#  'Punish/Reward',
#  'Naive Bayes',
#  'Cognitron',
#  'Continuous speech recognition by statistical methods',
#  'TD(0)',
#  'Internal functionality of visual invariants',
#  'Neocognitron',
#  'Kohonen network',
#  'Hopfield network',
#  'ASE+ACE',
#  'Learnability theory of language development',
#  'Error Propagation',
#  'Learning past tenses',
#  'PDP model for serial order',
#  'Back-propagation',
#  'Optimized Multi-Scale Edge Detection',
#  'NetTalk (dictionary)',
#  'NetTalk (transcription)',
#  'Motion-Driven 3D Feature Tracking',
#  'Adaptive Broom Balancer',
#  'MADALINE II',
#  'Q-learning',
#  'Innervator',
#  'Time-delay neural networks',
#  'Universal approximation via Feedforward Networks',
#  'Invariant image recognition',
#  'ALVINN',
#  'Zip CNN',
#  'MADALINE III',
#  'MLP as Bayesian Approximator',
#  'DIABETES',
#  'SRN-Encoded Grammatical Structures',
#  'TD-Gammon',
#  'REINFORCE in Stochastic Connectionism',
#  'Fuzzy NN',
#  'IBM-5',
#  'Markov-driven POS tagger',
#  'GroupLens',
#  'Multi-cause Binary Clustering',
#  'Iterative Bootstrapping WSD',
#  'Random Decision Forests',
#  'Support Vector Machines',
#  'System 11',
#  'HMM Word Alignment',
#  'Deep Blue',
#  'SVM for face detection',
#  'n-gram LM',
#  'Bidirectional RNN',
#  'LSTM',
#  'Sparse coding model for V1 receptive fields',
#  'RNN for speech',
#  'Probabilistic modeling for object recognition',
#  'Social and content-based classification',
#  'LeNet-5',
#  'LSTM with forget gates',
#  'Credibilty Network',
#  'IBM Model 4',
#  'Perceptron for Large Margin Classification',
#  'SVD in recommender systems',
#  'Peephole LSTM',
#  'FrameNet role labeling',
#  'Immediate trihead',
#  'Gradient Boosting Machine',
#  'Decision tree (classification)',
#  'Thumbs Up?',
#  'Joint Probability Machine Translation',
#  'NEAT in neuroevolution',
#  'Tagging via Viterbi Decoding',
#  'Maximum Entropy Models for machine translation',
#  'Web mining + Decision tree recommender',
#  'Statistical Shape Constellations',
#  'LDA',
#  'NPLM',
#  'Phrase-based translation',
#  'Unsupervised Scale-Invariant Learning',
#  'CNN Best Practices',
#  'A Bayesian Approach to Unsupervised One-Shot Learning of Object Categories',
#  'Max-Margin Markov Networks',
#  'GPU implementation of neural networks',
#  'Sandstorm (DARPA Grand Challenge I)',
#  'Automated WSD via WordNet',
#  'LIRA',
#  'SACHS',
#  'Hiero',
#  'ConvNet similarity metric',
#  'Histograms of Oriented Gradients',
#  'BiLSTM for Speech',
#  'Stanley (DARPA Grand Challenge 2)',
#  'TFE SVM',
#  'RL for helicopter flight',
#  'FAST',
#  'Spatial Pyramid Matching',
#  'DrLIM',
#  'CTC-Trained LSTM',
#  'Semantic Taxonomy Induction',
#  'DImensionality Reduction',
#  'Deep Belief Nets',
#  'Local Binary Patterns for facial recognition',
#  'Greedy layer-wise DNN training',
#  'Sparse Energy-Based Model',
#  'Empirical evaluation of deep architectures',
#  'Restricted Bolzmann machines',
#  'Regularized SVD for Collaborative Filtering',
#  'BLSTM for handwriting (1)',
#  'Enhanced Neighborhood-Based Filtering',
#  'BLSTM for handwriting (2)',
#  'Multiscale deformable part model',
#  'Deep Multitask NLP Network',
#  'Semi-Supervised Embedding for DL',
#  'Denoising Autoencoders',
#  'Stacked Semisuperviser Autoencoders',
#  'Boss (DARPA Urban Challenge)',
#  'Sparse digit recognition SVM',
#  'BigChaos 2008',
#  'Semantic Hashing',
#  'RBM Image Classifier',
#  'Deep Boltzmann Machines',
#  'Conv-DBN',
#  'GPU DBNs',
#  'Pragmatic Theory solution (Netflix 2009)',
#  'BellKor 2009',
#  'BigChaos OptiBlend',
#  'BellKor 2008',
#  'RL mapping instructions (games)',
#  'RL mapping instructions (troubleshooting)',
#  'MatrixFac for Recommenders',
#  'Polarity Classifier',
#  'BellKor 2007',
#  '3D city reconstruction',
#  'Learning deep architectures',
#  'Super-vector coding',
#  'Stacked Denoising Autoencoders',
#  '6-layer MLP (MNIST)',
#  'Feedforward NN',
#  'Word Representations',
#  'Mid-level Features',
#  'Deconvolutional Network',
#  'ReLU (LFW)',
#  'ReLU (NORB)',
#  'RBM-tuning',
#  'Fisher-Boost',
#  'YouTube Video Recommendation System',
#  'RNN 500/10 + RT09 LM (NIST RT05)',
#  'KN5 LM + RNN 400/10 (WSJ)',
#  'Culturome',
#  'Optimized Single-layer Net',
#  'Deep rectifier networks',
#  'RNN-SpeedUp',
#  'Cross-Lingual POS Tagger',
#  'Recursive sentiment autoencoder',
#  'Bayesian Starcraft',
#  'Adaptive Subgrad',
#  'Domain Adaptation',
#  'NLP from scratch',
#  'HOGWILD!',
#  'MCDNN (MNIST)',
#  'LBL',
#  'Ngram corpus',
#  'MV-RNN',
#  'Unsupervised High-level Feature Learner',
#  'Context-dependent RNN',
#  'LSTM-300units',
#  'RNN+LDA+KN5+cache',
#  'Bayesian automated hyperparameter tuning',
#  'RNN (SGD+CLR) (PTB)',
#  'RNN (SGD+CLR)',
#  'Textual Imager',
#  'Maxout Networks',
#  'PreTrans-3L-250H',
#  'SearchFusion',
#  'SemVec',
#  'Image Classification with the Fisher Vector: Theory and Practice',
#  'RNN+weight noise+dynamic eval',
#  'Mitosis',
#  'Word2Vec (large)',
#  'Word2Vec (small)',
#  'R-CNN (T-net)',
#  'TensorReasoner',
#  'TransE',
#  'DBLSTM',
#  'RNN for 1B words',
#  'Network in Network',
#  'DQN',
#  'Image generation',
#  'DOT(S)-RNN',
#  'OverFeat',
#  'SPN-4+KN5',
#  'GloVe (32B)',
#  'GloVe (6B)',
#  'DBN for NLP',
#  'HyperNEAT',
#  'Dropout: SVHN',
#  'GRUs',
#  'Two-stream ConvNets for action recognition',
#  'GANs',
#  'RNN-WER',
#  'DeepFace',
#  'Multiresolution CNN',
#  'SmooCT',
#  'AdClickNet',
#  'RNNsearch-50*',
#  'VGG19',
#  'Large regularized LSTM',
#  'Seq2Seq LSTM',
#  'Deeply-supervised nets',
#  'Spatially-Sparse CNN',
#  'LRCN',
#  'Fully Convolutional Networks',
#  'Cascaded LNet-ANet',
#  'Sparse Non-negative Matrix (SNM) estimation',
#  'NTM',
#  'ADAM (CIFAR-10)',
#  '4-gram + 8 DENN',
#  'DeepLab',
#  'SCRN(Structurally Constrained Recurrent Network)',
#  'MSRA (C, PReLU)',
#  'CRF-RNN',
#  'DQN-2015',
#  'Constituency-Tree LSTM',
#  'Stack RNN',
#  'genCNN + dyn eval',
#  'Fast R-CNN',
#  'Deep LSTM for video classification',
#  '2nd order FOFE-FNNLM',
#  'Trajectory-pooled conv nets',
#  'Draw',
#  'Faster R-CNN',
#  'GoogLeNet / InceptionV1',
#  'YOLO',
#  'BatchNorm',
#  'Skip-Thoughts',
#  'Search-Proven Best LSTM',
#  'Listen, Attend and Spell',
#  'LSTM-Char-Large',
#  'BPE',
#  'Deep Deterministic Policy Gradients',
#  'AlphaGo Fan',
#  'The Attentive Reader',
#  'Multi-scale Dilated CNN',
#  'Netflix Recommender System',
#  'Inception v3',
#  'DeepSpeech2 (English)',
#  'ResNet-110 (CIFAR-10)',
#  'ResNet-152 (ImageNet)',
#  'BPL',
#  'Advantage Learning',
#  'Variational (untied weights, MC) LSTM (Large)',
#  'AlphaGo Lee',
#  'Convolutional Pose Machines',
#  'A3C FF hs',
#  'Inception-ResNet-V2',
#  'Inceptionv4',
#  'SqueezeNet',
#  'Order-Embeddings of Images and Language',
#  'Binarized Neural Network (MNIST)',
#  'Symmetric Residual Encoder-Decoder Net',
#  'Gated HORNN (3rd order)',
#  'Spatiotemporal fusion ConvNet',
#  'DMN',
#  'R-FCN',
#  'Wide & Deep',
#  'fastText',
#  'VD-RHN',
#  'Character-enriched word2vec',
#  'Layer Normalization: Order embeddings of images and language',
#  'Layer Normalization: The Attentive Reader',
#  'Layer Normalization: Draw',
#  'Layer Normalization: Handwriting sequence generation',
#  'Layer Normalization: Skip Thoughts',
#  'Attend-Infer-Repeat',
#  'DenseNet-264',
#  'Multi-task Cascaded CNN',
#  'WaveNet',
#  'Youtube recommendation model',
#  'MS-CNN',
#  'Stacked hourglass network',
#  'ResNet-1001',
#  'ResNet-200',
#  'TSN',
#  'Wide Residual Network',
#  'Byte-mLSTM+emb+WN+VD',
#  'Zoneout + Variational LSTM (WT2)',
#  'Pointer Sentinel-LSTM (medium)',
#  'GNMT',
#  'Xception',
#  'Differentiable neural computer',
#  'SPIDER2',
#  'VD-LSTM+REAL Large',
#  'Neural Architecture Search with base 8 and shared embeddings',
#  'BIDAF',
#  'NASv3 (CIFAR-10)',
#  'Deeply-recursive ConvNet',
#  'ResNeXt-50',
#  'PolyNet',
#  'RefineNet',
#  'Image-to-image cGAN',
#  'Elastic weight consolidation',
#  'PointNet',
#  'GAN-Advancer',
#  'Neural cache model (size=2000) (300M)',
#  'Diabetic Retinopathy Detection Net',
#  'GCRN-M1, dropout',
#  'GCNN-14',
#  'YOLOv2',
#  'Fisher Kernel GMM',
#  'AlphaGo Master',
#  'Libratus',
#  'DeepStack',
#  'OR-WideResNet',
#  'MoE',
#  'DnCNN',
#  'Prototypical networks',
#  'Word-Independent-SRNN+KN5',
#  'AlexNet + coordinating filters',
#  'Mask R-CNN',
#  'WGAN-GP',
#  'MobileNet',
#  'DeepLab (2017)',
#  'Mnemonic Reader',
#  'Low-Cost Collaborative Network',
#  'SRGAN',
#  'Inflated 3D ConvNet',
#  'PointNet++',
#  'Reading Twice for NLU',
#  'EDSR',
#  'Transformer',
#  'HRA',
#  'DeepLabV3',
#  'NoisyNet-Dueling',
#  'ShuffleNet v1',
#  'JFT',
#  'AWD-LSTM',
#  'Densely Connected LSTM + Var. Dropout',
#  'NASNet-A',
#  'PSPNet',
#  'GSM',
#  'AWD-LSTM - 3-layer LSTM (tied) + continuous cache pointer (WT2)',
#  'RetinaNet-R50',
#  'OpenAI TI7 DOTA 1v1',
#  'EI-REHN-1000D',
#  'Cutout-regularized net',
#  'NeuMF (Pinterest)',
#  'Adversarial Joint Adaptation Network (ResNet)',
#  'GRU + p-tHSM (pretrain via Brown) (WT103)',
#  'D-LSRC(200)+KN5',
#  'NMM(LSTM+RNN)',
#  'GL-LWGC-AWD-MoS-LSTM + dynamic evaluation (WT2)',
#  'SENet (ImageNet)',
#  'PyramidNet',
#  'ISS',
#  'LSTM + dynamic eval',
#  'AWD-LSTM+WT+Cache+IOG (WT2)',
#  'AlphaGo Zero',
#  'LRSO-GAN',
#  'CapsNet (MNIST)',
#  'CapsNet (MultiMNIST)',
#  'ProgressiveGAN',
#  'PhraseCond',
#  'S-Norm',
#  'DCN+',
#  'Fraternal dropout + AWD-LSTM 3-layer (WT2)',
#  'AWD-LSTM-MoS + dynamic evaluation (WT2, 2017)',
#  'TriNet',
#  'PNAS-net',
#  'PNASNet-5',
#  'AlphaZero',
#  '2-layer-LSTM+Deep-Gradient-Compression',
#  'Tacotron 2',
#  'RNNLM + Dynamic KL Regularization (WT2)',
#  'Refined Part Pooling',
#  'ULM-FiT',
#  'QRNN',
#  'ELMo',
#  'IMPALA',
#  'AmoebaNet-A (F=190)',
#  'AmoebaNet-A (F=448)',
#  'DeepLabV3+',
#  'ENAS',
#  'TCN (P-MNIST)',
#  'Multipop Adaptive Continuous Stack (WT2)',
#  'TCN (148M)',
#  'Spectrally Normalized GAN',
#  'Residual Dense Network',
#  'Chinese - English translation',
#  'LSTM (2018)',
#  'Rotation',
#  '4 layer QRNN (h=2500)',
#  'LSTM (Hebbian, Cache, MbPA)',
#  'YOLOv3',
#  'Diffractive Deep Neural Network',
#  'RNMT+',
#  'DNCON2',
#  'TF-LM-discourse LSTM (PTB)',
#  'TF-LM-discourse LSTM (WT2)',
#  'ResNeXt-101 32x48d',
#  'LSTM+Noise(Beta)',
#  'Dropout-LSTM+Noise(Bernoulli) (WT2)',
#  'aLSTM(depth-2)+RecurrentPolicy (WT2)',
#  'RHN(depth=40)',
#  'RHN+HSG(depth=40)',
#  '2-layer skip-LSTM + dropout tuning (WT2)',
#  'Relational Memory Core',
#  'MobileNetV2',
#  'DARTS',
#  'S + I-Attention (3)',
#  'QT-Opt',
#  'ShuffleNet v2',
#  'FTW',
#  'Population-based DRL',
#  'RCAN',
#  'Big-Little Net (speech)',
#  'Big-Little Net (vision)',
#  'Big-Little Net',
#  'RGC+ASQ (WT2)',
#  'AWD-LSTM-MoS+PDR + dynamic evaluation (WT2)',
#  'Big Transformer for Back-Translation',
#  '(ensemble): AWD-LSTM-DOC (fin) × 5 (WT2)',
#  'ESRGAN',
#  'Transformer + Simple Recurrent Unit',
#  'AWD-LSTM-MoS + dynamic evaluation (WT2, 2018)',
#  'LSTM+NeuralCache',
#  'Transformer (Adaptive Input Embeddings)',
#  'BigGAN-deep 512x512',
#  'BERT-Large',
#  'DeepConPred2',
#  'MetaMimic',
#  'TrellisNet',
#  'Mesh-TensorFlow Transformer 2.9B (translation)',
#  'Mesh-TensorFlow Transformer 4.9B (language modelling)',
#  'Fine-tuned-AWD-LSTM-DOC(fin)',
#  'Multi-cell LSTM',
#  'GPipe (Amoeba)',
#  'GPipe (Transformer)',
#  'DMPFold',
#  'Transformer ELMo',
#  'Transformer + Average Attention Network',
#  'Decoupled weight decay regularization',
#  'Transformer-XL (257M)',
#  'Mono3D++',
#  'H-LSTM+wg+rcp+rcg+wp',
#  'TSLM+MoS (WT2)',
#  'MT-DNN',
#  'Hanabi 4 player',
#  'Compress-LSTM (66M)',
#  'GPT-2 (1.5B)',
#  'ProxylessNAS',
#  'KataGo',
#  'NMT Transformer 437M',
#  'UniRep',
#  'SciBERT',
#  'FAIRSEQ Adaptive Inputs',
#  'WeNet (Penn Treebank)',
#  'WeNet (WT2)',
#  'True-Regularization+Finetune+Dynamic-Eval',
#  'True-Regularization+Finetune',
#  'Transformer-XL + RMS dynamic eval',
#  'SpecAugment',
#  'LTM',
#  'BERT-Large-CAS (PTB+WT2+WT103)',
#  'DANet',
#  'Neuro-Symbolic Concept Learner',
#  'ResNet-50 Billion-scale',
#  'RaptorX-Contact',
#  'ResNeXt-101 Billion-scale',
#  'AWD-LSTM-DRILL + dynamic evaluation† (WT2)',
#  'CPC v2',
#  'RSM',
#  'EfficientNet-L2',
#  'MnasNet-A1 + SSDLite',
#  'MnasNet-A3',
#  'Grover-Mega',
#  'DLRM-2020',
#  'XLM',
#  'XLNet',
#  'AMDIM',
#  'Transformer-XL Large + Phrase Induction',
#  'AWD-LSTM + MoS + Partial Shuffled',
#  'Char-CNN-BiLSTM',
#  'FixRes ResNeXt-101 WSL',
#  'PG-SWGAN',
#  'Stacked-LSTM+Pruning',
#  'LaNet-L (CIFAR-10)',
#  'Walking Minotaur robot',
#  'TAPE Transformer',
#  'Tensorized Transformer (257M)',
#  'RoBERTa Large',
#  'All-attention network + adaptive span',
#  'BigBiGAN',
#  'Pluribus',
#  'R-Transformer',
#  'RNN + char4-MS-vec',
#  'LSTM+Adam+Lookahead',
#  'EN^2AS with performance reward',
#  'L_UL-seq',
#  'TripletRes',
#  'LSTM-Large+Behaviorial-Gating',
#  'DEQ-Transformer (Medium, Adaptive Embedding)',
#  'UDSMProt',
#  'Mogrifier (d2, MoS2, MC) + dynamic eval',
#  'ResNet-152 + ObjectNet',
#  'Megatron-BERT',
#  'Hide and Seek',
#  'Megatron-LM (8.3B)',
#  'Alleviated TOI 10 (WT103)',
#  'Transformer-XL+AdamGapAware(GA)',
#  'Adaptive Inputs + LayerDrop',
#  'ALBERT',
#  'DistilBERT',
#  'M4-50B',
#  'dense-IndRNN+dynamic eval',
#  "Rubik's cube ADR robot",
#  'LSTM(large)+Sememe+cell',
#  'T5-11B',
#  'T5-3B',
#  'Amended-DARTS',
#  'BART-large',
#  'AlphaStar',
#  'Base LM + kNN LM + Continuous Cache',
#  'XLM-RoBERTa',
#  'Self-Attention and Convolutional Layers',
#  'Sandwich Transformer',
#  'CamemBERT',
#  'Noisy Student (L2)',
#  'MoCo',
#  'Compressive Transformers for Long-Range Sequence Modelling',
#  'MuZero',
#  'Transformer - LibriVox + Decoding/Rescoring',
#  'Photo-Geometric Autoencoder',
#  'Transformer-XL DeFINE (141M)',
#  'bRSM + cache',
#  'StarGAN v2',
#  'MMLSTM',
#  'OpenAI Five Rerun',
#  'OpenAI Five',
#  'DD-PPO',
#  'Big Transfer (BiT-L)',
#  'MicroNet (Adaptive, Cache)',
#  'AlphaFold',
#  'ContextNet + Noisy Student',
#  'Meena',
#  'Theseus 6/768',
#  'Perceiver IO (optical flow)',
#  'TaLK Convolution',
#  'ALBERT-xxlarge',
#  'SimCLR',
#  'Turing-NLG',
#  'Feedback Transformer',
#  'Temporal Convolutional Attention-based Network(TCAN) (WT2)',
#  'LSTM-3-layer+Gadam',
#  'TransformerXL + spectrum control',
#  'Routing Transformer',
#  'ProGen',
#  'Tensor-Transformer(1core)+PN (WT103)',
#  'ELECTRA',
#  'MetNet',
#  'Agent57',
#  'DiffStk-MRNN',
#  'MobileBERT',
#  'CURL',
#  'Go-explore',
#  'Cube-Space AutoEncoder',
#  'Once for All',
#  'Segatron XL large, M=384',
#  'ATLAS',
#  'UnifiedQA',
#  'NAS+ESS (156M)',
#  'ContextNet',
#  'ONLSTM-SYD',
#  'Conformer',
#  'Decay RNN',
#  'rTop-k(distributed setting)',
#  'Retrieval-Augmented Generator',
#  'DETR',
#  'GPT3-6.7B (rerun of original)',
#  'GPT-3 175B (davinci)',
#  '6-Layer-Tensor-Transformer+AdaHessian',
#  'SqueezeBERT',
#  'Transformer-XL+AdamP',
#  'Transformer-XL+WN+AdamP',
#  'iGPT-XL',
#  'iGPT-L',
#  'GShard (600B)',
#  'GShard (dense)',
#  'DLRM-2021',
#  'SemExp',
#  '1-layer-LSTM',
#  'Hopfield Networks (2020)',
#  'EfficientDet',
#  'GPT2-LayerFusion-WS',
#  'TransformerXL-LayerFusion-CA',
#  'Grown to Prune Two-layer stacked LSTM',
#  'mBART-50',
#  'DeLight',
#  'ERNIE-GEN (large)',
#  'Transformer+Recurrent Windows of Context',
#  'ESM1-670M (UR50/D)',
#  'ProBERTa',
#  'PAR Transformer Large',
#  'Integer Transformer',
#  'Frage-AWD-LSTM-MemoryAug-NeuralCache (WT2)',
#  'LUKE',
#  'Memformer (4 encoder + 16 decoder)',
#  'Conformer + Wav2vec 2.0 + Noisy Student',
#  'mT5-XXL',
#  'GBERT-Large',
#  'German ELECTRA Large',
#  'ViT-Base/32',
#  'ViT-Huge/14',
#  'CryptoGRU',
#  'wave2vec 2.0 LARGE',
#  'SimCLRv2',
#  'AWD-FWM (WT2)',
#  'KEPLER',
#  'AlphaFold 2',
#  'CPM-Large',
#  'VQGAN + CLIP',
#  'RaSoR',
#  'CT-MoS + DynamicEval (WT2)',
#  'CT-MoS (WT2)',
#  'AraGPT2-Mega',
#  'ERNIE-Doc (247M)',
#  'Shortformer',
#  'Subformer (122M)',
#  'CLIP (ResNet-50)',
#  'CLIP (ViT L/14@336px)',
#  'DALL-E',
#  'Transformer-XL + AutoDropout (WT2)',
#  'BigSSL',
#  'Wu Dao - Wen Yuan',
#  'Switch',
#  'DeiT',
#  'Selfish-RNN (SNT-ASGD) Stacked LSTMs',
#  'top-down frozen classifier',
#  'MSA Transformer',
#  'Rational DQN Average',
#  'Linear Transformer (large)',
#  'SRU++ Large',
#  'Wu Dao - Wen Lan',
#  'Wu Dao - Wen Su',
#  'Wu Dao - Wen Hui',
#  'M6-10B',
#  'Meta Pseudo Labels',
#  'M6-100B',
#  'RFA-GATE-Gaussian-Stateful Big',
#  'ProteinGAN',
#  'Generative BST',
#  'M6-T',
#  'ResNet-RS',
#  'GLM-10B',
#  'GPT-Neo-2.7B',
#  'Unicorn',
#  'T2R + Random Init',
#  'TransfoRNN(d=1024)(2-layer) (WT2)',
#  'Transformer-C',
#  'Megatron-LM (1T)',
#  'DLRM-12T',
#  'PLUG',
#  'DiffQ Transformer (16L)',
#  'SPALM + kNN',
#  'ViT + DINO',
#  'GPT-J-6B',
#  'Transformer-XL + SIS',
#  'ProtBERT-BFD',
#  'ProtT5-XXL-BFD',
#  'ProtT5-XXL',
#  'ADM',
#  'Fairseq + UID: variance',
#  'Multitask Unified Model (MUM)',
#  'MedBERT',
#  'ConSERT',
#  'Transformer local-attention (NesT-B)',
#  'CogView',
#  'ByT5-XXL',
#  'CODA',
#  'Wu Dao 2.0',
#  'GPT2-Large+LHOPT',
#  'AFP+FPI (PTB)',
#  'ViT-G/14',
#  'EMDR',
#  'CoAtNet',
#  'DeBERTa',
#  'Denoising Diffusion Probabilistic Models (LSUN Bedroom)',
#  'Delta RNN (+ full context)',
#  'ALIGN',
#  'EfficientNetV2',
#  'CPM-2',
#  'Fold2Seq',
#  'DEQ-Transformer (Post-LN) + Jacobian Regularisation',
#  'Adaptive Input Transformer + RD',
#  'ERNIE 3.0',
#  'Codex',
#  'FNetAR Medium',
#  'HuBERT',
#  'GOAT',
#  'SEER',
#  '6-Act Tether',
#  'FMMformer (2-kernel fast weight + Band20)',
#  'YOLOX-X',
#  'W2v-BERT',
#  'Zidong Taichu',
#  'Jurassic-1-Jumbo',
#  'GPT-2 (1.5B, Curriculum Learning 45K)',
#  'XLMR-XXL',
#  'ProteinLM',
#  'ALiBi (L=3072, Lvalid = 3072)',
#  '$\\infty$-former (SM)',
#  'FLAN 137B',
#  'MEB',
#  'RNS-RNN',
#  'PermuteFormer',
#  'NLM',
#  'HyperCLOVA',
#  'MegaMolBART',
#  'DLRM-2022',
#  'PLATO-XL',
#  'TrOCR',
#  'AlphaFold-Multimer',
#  'M6-10T',
#  'Megatron-Turing NLG 530B',
#  'Yuan 1.0',
#  'TOME',
#  'KnGPT2',
#  'T0-XXL',
#  'PAGnol-XL',
#  'MGK 4 heads (medium)',
#  'GPT-2 (fine-tuned with HYDRA)',
#  'base LM+GNN+kNN',
#  'WD+LR+M',
#  'Cloob',
#  'DALL-E mini',
#  'Eve',
#  'Scatterbrain',
#  'EfficientZero',
#  'S4',
#  'Projected GAN',
#  'CodeT5-base',
#  'GPT2+CoreLM+Fine-Tuning',
#  'GPT-2 (AMPS)',
#  'Japanese dialog transformers',
#  'Masked Autoencoders',
#  'KoGPT',
#  'EquiDock',
#  'ViT-G/14 (LiT)',
#  'Swin Transformer V2',
#  'BASIC-L',
#  'Florence',
#  'Persia',
#  'NÜWA',
#  'Transformer LM + MinSen',
#  'Quantized ADMM',
#  'GPT-2-Medium+Pixelfly',
#  'CTR-BERT',
#  'DeBERTaV3-large + KEAR',
#  'Student of Games',
#  'Gopher (280B)',
#  'Engine-XL(NE)',
#  'GLaM',
#  'LongT5',
#  'HSO',
#  'Contriever',
#  'XGLM',
#  'GLIDE',
#  'XGLM-7.5B',
#  'Fairseq-dense 13B',
#  'MoE-1.1T',
#  'LDM-1.45B',
#  'ERNIE 3.0 Titan',
#  'Vespa',
#  'ERNIE-ViLG',
#  'Detic',
#  'Japanese-GPT-1B',
#  'data2vec (vision)',
#  'data2vec (speech)',
#  'data2vec (language)',
#  'AbLang',
#  'OntoProtein',
#  'SPALM + RelationLM',
#  'Primer',
#  'TransformerXL+RelationLM',
#  'InstructGPT',
#  'DARK',
#  'AlphaCode',
#  'RETRO-7B',
#  'GPT-NeoX-20B',
#  'LaMDA',
#  'MuZero VP9',
#  'Midjourney V1',
#  'ST-MoE',
#  'DeepNet',
#  'Statement Curriculum Learning',
#  'MegaSyn',
#  'GPT3-6.7B + muP',
#  'ViT-G (model soup)',
#  'Transformer Large + HCP',
#  'Segatron-XL large, M=384 + HCP',
#  'MemSizer',
#  'BaGuaLu',
#  'Chinchilla',
#  'NoPos',
#  'Monarch-GPT-2-Medium',
#  'PaLM (540B)',
#  'DALL·E 2',
#  'BERT-RBP',
#  'VLM-4',
#  'STT Conformer-Transducer XL',
#  'Stable Diffusion (LDM-KL-8-G)',
#  'Sparse all-MLP',
#  'LaMemo',
#  'CogView2',
#  'Flamingo',
#  'OPT-175B',
#  'Jurassic-X',
#  'ASE',
#  'UL2',
#  'Gato',
#  'SimCSE',
#  'LSTM+GraB',
#  'Imagen',
#  'TRIMELMext (247M)',
#  'Tranception',
#  'CogVideo',
#  'B2T connection (16L)',
#  'Diffusion-GAN',
#  'DITTO',
#  'LiMoE',
#  'BIG-G 137B',
#  'EGRU (WT2)',
#  'MetaLM',
#  'CoCa',
#  'Unified-IO',
#  'Parti',
#  'YaLM',
#  'CodeWhisperer',
#  'GPT-SW3',
#  'ProGen2-xlarge',
#  'DALL-E mega',
#  'Minerva (540B)',
#  'BLOOM-7.1B',
#  'CodeT5-large',
#  'NLLB',
#  'Delphi',
#  'Transformer-XL + RMT',
#  'Rita-XLarge',
#  'YuYan 11B',
#  'ESM2-15B',
#  'OmegaPLM',
#  'GPT-NeoX-Japanese',
#  'ProtGPT2',
#  'AlexaTM 20B',
#  'GLM-130B',
#  'BlenderBot 3',
#  'Luminous-supreme',
#  'PaLM-SayCan',
#  'BEIT-3',
#  'PaLI',
#  'CLIP ViT-H/14 - LAION-2B',
#  'NeMO Megatron GPT 20B',
#  'DistilProtBert',
#  'Whisper',
#  'Sparrow',
#  'Make-A-Video',
#  'NMST+GPT-2',
#  'VRNS-RNN-3-3-5',
#  'Imagen Video',
#  'Phenaki',
#  'Decaying Fast Weights Transformer (WT-103)',
#  'TPM-LVD',
#  'GenSLM',
#  "Instruct-GPT + Mind's Eye",
#  'Diplodocus',
#  'GPT-2 + Progressive LRD',
#  'Flan-T5 11B',
#  'Flan-PaLM 540B',
#  'LMSI-Palm',
#  'U-PaLM (540B)',
#  'Verbatim Memory Transformer (182M)',
#  'EnCodec',
#  'Tk-Instruct',
#  'ADP-FAIRSEQ+NGRAMRES',
#  'retrieval-quality-kNN-LMs',
#  'Transformer-XL + PowerSGD + L-Greco',
#  'Taiyi-Stable Diffusion',
#  'eDiff-I',
#  'mT0-13B',
#  'BLOOMZ-176B',
#  'Mogrifier RLSTM (WT2)',
#  'BLOOM-176B',
#  'InternImage',
#  'AltCLIP',
#  'EVA-01',
#  'Luminous Sparse',
#  'Galactica',
#  'Fusion in Encoder',
#  'AR-LDM',
#  'CICERO',
#  'ALM 1.0',
#  'DiT-XL/2 + Discriminator Guidance',
#  'Discriminator Guidance',
#  'GPT-3.5 (text-davinci-003)',
#  'ChatGPT (gpt-3.5-turbo)',
#  'DeepNash',
#  'ZymCTRL',
#  'Transformer + GFM',
#  'Whisper v2',
#  'Transformer-XL + FWL',
#  'TranceptEve',
#  'RT-1',
#  'OPT-IML (175B)',
#  'Hybrid H3-2.7B',
#  'SparseOPT-175B',
#  'VALL-E',
#  'SantaCoder',
#  'Nucleotide Transformer',
#  'Ankh_base',
#  'Ankh_large',
#  'Adaptive Agent',
#  'GPT-2+Active-SGD (WT 103)',
#  'MusicLM',
#  'DDPM-IP (CelebA)',
#  'BLIP-2 (Q-Former)',
#  'Flan T5-XXL + BLIP-2',
#  'UniPi',
#  'CD-GraB (WT103)',
#  'Gen-1',
#  'ProteinDT',
#  'ViT-22B',
#  'BASIC-L + Lion',
#  'Anthropic LM 175B',
#  'E-SPA',
#  'Hyena-3-slim',
#  'LLaMA-7B',
#  'LLaMA-65B',
#  'CodeGen-Mono 16.1B',
#  'Cohere Command',
#  'gpt-sw3-40b',
#  'Jurassic-2 Jumbo',
#  'Palmyra Large 20B',
#  'DiT-XL/2',
#  'Flan UL2',
#  'AudioGen',
#  'PaLM-E',
#  'VALL-E X',
#  'Claude',
#  'LEP-AD',
#  'Falcon-40B',
#  'GPT-4',
#  'Gen-2',
#  'Firefly',
#  'LightOn Mini',
#  'Sparse Wide GPT-3 Small',
#  'VideoMAE V2',
#  'Vicuna-7B',
#  'BloombergGPT',
#  'Vicuna-13B',
#  'Pythia-12b',
#  'Segment Anything Model',
#  'gLM',
#  'Incoder-6.7B',
#  'Dolly 2.0-12b',
#  'Anthropic LM 52B',
#  'DINOv2',
#  'LLaVA',
#  'Claude 1.3',
#  'MOSS-Moon-003',
#  'WizardLM 70B',
#  'Falcon-7B',
#  'WizardLM-7B',
#  'Agile Soccer Robot',
#  'MosaicML Diffusion',
#  'OpenLLaMA-13B',
#  'Perfusion',
#  'CodeGen2',
#  'MPT-7B (base)',
#  'StarCoder',
#  'ImageBind',
#  ...]

# %% [markdown]
# Use the below to check data availability for specific systems

# %%
# system = 'WizardLM-7B'
# row = cost_df.loc[cost_df['System'] == system]
# print('Cost:', row['Cost'].values[0])
# print('Training hardware:', row['Training hardware'].values[0])
# print('Training time (hours):', row['Training time (hours)'].values[0])
# print('Hardware quantity:', row['Hardware quantity'].values[0])
# print('Hardware utilization:', row['Hardware utilization'].values[0])

# %% [markdown]
# # Apply inflation adjustment

# %%
cost_df['Cost'].dropna()
# Out:
# 971    1.783296e+05
# 970    1.857600e+04
# 928    6.182400e+02
# 923    3.096000e+04
# 885    3.001965e+05
#            ...
# 24     8.590207e+04
# 20     1.150248e+07
# 18     2.990346e+06
# 9      3.346887e+05
# 4      6.792973e+06
# Name: Cost, Length: 220, dtype: float64

# %%
cost_df = adjust_column_for_inflation(cost_df, 'Cost', 'data/PCU518210518210.csv', '2023-12-01')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15396\1560023325.py in <module>
# ----> 1 cost_df = adjust_column_for_inflation(cost_df, 'Cost', 'data/PCU518210518210.csv', '2023-12-01')
#
# ~\OneDrive\Documents\GitHub\training-cost-trends\inflation.py in adjust_column_for_inflation(df, cost_colname, path_to_price_index, to_year_month)
#      16 def adjust_column_for_inflation(df, cost_colname, path_to_price_index, to_year_month):
#      17     price_index = pd.read_csv(path_to_price_index)
# ---> 18     df[cost_colname + ' (inflation-adjusted)'] = df.apply(
#      19         adjust_value_for_inflation, axis=1, args=(cost_colname, price_index, to_year_month)
#      20     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
#     859         # wrap results
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     871             for i, v in enumerate(series_gen):
#     872                 # ignore SettingWithCopy here in case the user mutates
# --> 873                 results[i] = self.f(v)
#     874                 if isinstance(results[i], ABCSeries):
#     875                     # If we have a view on v, we need to make a copy because
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in f(x)
#     136
#     137             def f(x):
# --> 138                 return func(x, *args, **kwargs)
#     139
#     140         else:
#
# ~\OneDrive\Documents\GitHub\training-cost-trends\inflation.py in adjust_value_for_inflation(row, cost_colname, price_index, to_year_month)
#       8     from_date = str(row['Publication date'])
#       9     from_year_month = from_date.rsplit('-', maxsplit=1)[0] + '-01'
# ---> 10     from_price_index = price_index[price_index['DATE'] == from_year_month]['PCU518210518210'].values[0]
#      11     to_price_index = price_index[price_index['DATE'] == to_year_month]['PCU518210518210'].values[0]
#      12     adjust_factor = to_price_index / from_price_index
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
cost_df['Cost (inflation-adjusted)'].dropna()

# %%
assert cost_df['Cost (inflation-adjusted)'].notna().sum() == cost_df['Cost'].notna().sum()

# %% [markdown]
# # Regression

# %%
cost_df['Publication date (float)'] = datetime_to_float_year(pd.to_datetime(cost_df['Publication date']))

# %%
reg_results = fit_ols_regression(cost_df, ['Publication date (float)'], 'Cost (inflation-adjusted)', logy=True)
reg_results.summary()

# %%
with open(f'{results_dir}/regression_results.out', 'w') as f:
    with redirect_stdout(f):
        print_growth_rates(reg_results)
print_growth_rates(reg_results)

# %%
pred_start_year = 2015
pred_end_year = 2025
pred_start_date = f'{pred_start_year}-01-01'
pred_end_date = f'{pred_end_year}-01-01'

pred_years = pd.DataFrame({'Publication date (float)': np.linspace(pred_start_year, pred_end_year, 100)})
pred_years

# %%
predicted_cost_df = get_predictions(reg_results, pred_years, ['Publication date (float)'])
predicted_cost_df['Publication date'] = predicted_cost_df['Publication date (float)'].apply(float_year_to_datetime)
predicted_cost_df

# %% [markdown]
# # Export data

# %%
keep_cols = [
    'System',
    'Domain',
    # 'Task',
    'Model accessibility',
    'Reference',
    'Publication date',
    'Organization',
    'Parameters',
    'Training compute (FLOP)',
    'Training dataset size (datapoints)',
    'Epochs',
    'Training time (hours)',
    'Training hardware',
    'Country (from Organization)',
    'Base model',
    'Finetune compute (FLOP)',
    'Hardware quantity',
    'Hardware utilization',
    'Training cloud compute vendor',
    'Training data center',
    # 'Training time (chip hours)',
    'Cost',
    # 'Cost (inflation-adjusted)',
]
cost_df[keep_cols]
# Out:
#                                   System    Domain  \
# 1292                             Theseus  Robotics
# 1291                               SNARC  Robotics
# 1290                   Genetic algorithm     Other
# 1289              Self Organizing System     Other
# 1288  Sequence-based pattern recognition    Vision
# ...                                  ...       ...
# 4                            Llama 3-70B  Language
# 3                          SenseNova 5.0  Language
# 2                       phi-3-medium 14B  Language
# 1                          Qwen 1.5 110B  Language
# 0                             Fugaku-LLM  Language
#
#                Model accessibility  \
# 1292                           NaN
# 1291                           NaN
# 1290                           NaN
# 1289                           NaN
# 1288                           NaN
# ...                            ...
# 4     Open access (restricted use)
# 3           Hosted access (no API)
# 2                       Unreleased
# 1                      Open source
# 0                      Open source
#
#                                               Reference Publication date  \
# 1292                                       Mighty Mouse       1950-07-02
# 1291  A Neural-Analogue Calculator Based upon a Prob...       1952-01-08
# 1290            Numerical testing of evolution theories       1954-07-02
# 1289  Generalization of pattern recognition in a sel...       1955-03-01
# 1288           Pattern recognition and modern computers       1955-03-01
# ...                                                 ...              ...
# 4     Introducing Meta Llama 3: The most capable ope...       2024-04-18
# 3                                                   NaN       2024-04-23
# 2     Phi-3 Technical Report: A Highly Capable Langu...       2024-04-23
# 1     Qwen1.5-110B: The First 100B+ Model of the Qwe...       2024-04-25
# 0     Release of “Fugaku-LLM” – a large language mod...       2024-05-10
#
#                                            Organization    Parameters  \
# 1292                                  Bell Laboratories  4.000000e+01
# 1291                                 Harvard University  4.000000e+01
# 1290                       Institute for Advanced Study           NaN
# 1289        Massachusetts Institute of Technology (MIT)  2.250000e+02
# 1288        Massachusetts Institute of Technology (MIT)           NaN
# ...                                                 ...           ...
# 4                                               Meta AI  7.000000e+10
# 3                                             SenseTime           NaN
# 2                                             Microsoft  1.400000e+10
# 1                                               Alibaba  1.100000e+11
# 0     Tohoku University,CyberAgent,Tokyo Institute o...  1.300000e+10
#
#       Training compute (FLOP)  Training dataset size (datapoints)  Epochs  \
# 1292             4.000000e+01                        4.000000e+01     NaN
# 1291                      NaN                                 NaN     NaN
# 1290                      NaN                                 NaN     NaN
# 1289                      NaN                        2.560000e+02     NaN
# 1288                      NaN                                 NaN     NaN
# ...                       ...                                 ...     ...
# 4                6.300000e+24                        1.500000e+13     NaN
# 3                         NaN                        1.670000e+12     NaN
# 2                4.032000e+23                        4.800000e+12     NaN
# 1                         NaN                                 NaN     NaN
# 0                2.964000e+22                        3.800000e+11     NaN
#
#       Training time (hours) Training hardware Country (from Organization)  \
# 1292                    NaN               NaN    United States of America
# 1291                    NaN               NaN    United States of America
# 1290                    NaN               NaN    United States of America
# 1289                    NaN               NaN    United States of America
# 1288                    NaN               NaN    United States of America
# ...                     ...               ...                         ...
# 4                       NaN  NVIDIA H100 SXM5    United States of America
# 3                       NaN               NaN                   Hong Kong
# 2                       NaN               NaN    United States of America
# 1                       NaN               NaN                       China
# 0                       NaN               NaN                 Japan,Japan
#
#      Base model  Finetune compute (FLOP)  Hardware quantity  \
# 1292        NaN                      NaN                NaN
# 1291        NaN                      NaN                NaN
# 1290        NaN                      NaN                NaN
# 1289        NaN                      NaN                NaN
# 1288        NaN                      NaN                NaN
# ...         ...                      ...                ...
# 4           NaN                      NaN            16000.0
# 3           NaN                      NaN                NaN
# 2           NaN                      NaN                NaN
# 1           NaN                      NaN                NaN
# 0           NaN                      NaN                NaN
#
#       Hardware utilization Training cloud compute vendor Training data center  \
# 1292                   NaN                           NaN                  NaN
# 1291                   NaN                           NaN                  NaN
# 1290                   NaN                           NaN                  NaN
# 1289                   NaN                           NaN                  NaN
# 1288                   NaN                           NaN                  NaN
# ...                    ...                           ...                  ...
# 4                      0.4                           NaN                  NaN
# 3                      NaN                           NaN                  NaN
# 2                      NaN                           NaN                  NaN
# 1                      NaN                           NaN                  NaN
# 0                      NaN                           NaN                  NaN
#
#               Cost
# 1292           NaN
# 1291           NaN
# 1290           NaN
# 1289           NaN
# 1288           NaN
# ...            ...
# 4     6.792973e+06
# 3              NaN
# 2              NaN
# 1              NaN
# 0              NaN
#
# [1238 rows x 20 columns]

# %%
cost_df[keep_cols].to_csv('results/price dataset cloud.csv', index=False)

# %% [markdown]
# # Plots

# %%
fig = px.scatter(
    cost_df,
    x='Publication date',
    y='Cost (inflation-adjusted)',
    text='System',
    log_y=True,
)
fig.update_traces(textposition='top center')

# no legend
fig.update_layout(showlegend=False)

# axis labels
fig.update_xaxes(title_text='Publication date')
fig.update_yaxes(title_text='Cost (2023 USD, log scale)')

# title
fig.update_layout(title_text=get_cost_plot_title(estimation_method, compute_threshold_method, compute_threshold))

# update size
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    title_font=dict(
        size=16,
    )
)

# font size
fig.update_layout(
    font=dict(
        size=14,
    )
)

# axis limits
fig.update_xaxes(range=['2015-01-01', '2025-01-01'])

# margins
fig.update_layout(margin=dict(l=10, r=10, t=40, b=10))

save_plot(fig, results_dir, 'cost_scatter')

fig.show()

# %%
label_systems = ['GNMT', 'AlphaGo Master', 'AlphaGo Zero', 'AlphaZero', 'DALL-E', 'GPT-3 175B (davinci)', 'PaLM (540B)', 'Llama 2-70B', 'Falcon 180B', 'GPT-4', 'Gemini Ultra', 'Inflection-2']

tpu_mask = cost_df['Training hardware'].str.contains('TPU', na=False)
tpu_cost_df = cost_df.loc[tpu_mask]
gpu_cost_df = cost_df.loc[~tpu_mask]

fig = px.scatter(
    gpu_cost_df,
    x='Publication date',
    y='Cost (inflation-adjusted)',
    log_y=True,
)
fig.add_scatter(
    x=tpu_cost_df['Publication date'],
    y=tpu_cost_df['Cost (inflation-adjusted)'],
    mode='markers',
    marker_symbol='circle-open' if estimation_method != 'cloud' else 'circle',
    name='Using equivalent price of TPU' if estimation_method != 'cloud' else '',
    showlegend=estimation_method != 'cloud',
)
fig.add_scatter(
    x=gpu_cost_df.loc[gpu_cost_df['System'].isin(label_systems)]['Publication date'],
    y=gpu_cost_df.loc[gpu_cost_df['System'].isin(label_systems)]['Cost (inflation-adjusted)'],
    text=gpu_cost_df.loc[gpu_cost_df['System'].isin(label_systems)]['System'],
    mode='text',
    showlegend=False,
)
fig.add_scatter(
    x=tpu_cost_df.loc[tpu_cost_df['System'].isin(label_systems)]['Publication date'],
    y=tpu_cost_df.loc[tpu_cost_df['System'].isin(label_systems)]['Cost (inflation-adjusted)'],
    text=tpu_cost_df.loc[tpu_cost_df['System'].isin(label_systems)]['System'],
    mode='text',
    showlegend=False,
)

# Marker color
fig.update_traces(
    marker=dict(
        color='rgb(0,100,200)',
    ),
    selector=dict(mode='markers'),
)

# Shade in CI
fig.add_scatter(
    x=predicted_cost_df['Publication date'],
    y=10**predicted_cost_df['mean_ci_lower'],
    mode='lines',
    line=dict(width=0),
    showlegend=False,
)
fig.add_scatter(
    x=predicted_cost_df['Publication date'],
    y=10**predicted_cost_df['mean_ci_upper'],
    mode='lines',
    fill='tonexty',
    fillcolor='rgba(0,100,200,0.2)',
    line=dict(width=0),
    name='95% CI of mean',
)
fig.add_scatter(
    x=predicted_cost_df['Publication date'],
    y=10**predicted_cost_df['mean'],
    mode='lines',
    line=dict(color='rgb(0,100,200)'),
    name=f'Regression mean (growth rate: {10**reg_results.params[1]:.1f}x per year)',
)

fig.update_traces(textposition='top center')

# axis limits
fig.update_xaxes(range=['2015-01-01', '2025-01-01'])
if estimation_method == 'hardware-acquisition':
    fig.update_yaxes(range=[4, 10])
else:
    fig.update_yaxes(range=[1, 9])

# legend on bottom-right of the axes
fig.update_layout(
    legend=dict(
        x=0.45,
        y=0.05,
    )
)

# axis labels
fig.update_xaxes(title_text='Publication date')
fig.update_yaxes(title_text='Cost (2023 USD, log scale)')

# title
fig.update_layout(title_text=get_cost_plot_title(estimation_method, compute_threshold_method, compute_threshold))

# update size
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    title_font=dict(
        size=16,
    )
)

# font size
fig.update_layout(
    font=dict(
        size=14,
    )
)

# axis limits
fig.update_xaxes(range=[pred_start_date, pred_end_date])

# margins
fig.update_layout(margin=dict(l=10, r=10, t=40, b=10))

save_plot(fig, results_dir, 'cost_regression')

fig.show()

# %% [markdown]
# # Cost components

# %%
cost_component_names = [
    'AI accelerator chip cost',
    'Other server components cost',
    'Cluster-level interconnect cost',
    'Energy cost',
]

# %%
for key in cost_component_names:
    component_cost_df[f"{key} (%)"] = component_cost_df[key] / component_cost_df['Cost'] * 100
component_cost_df['AI accelerator chip cost (%)']

# %%
cost_component_pc_names = [name + ' (%)' for name in cost_component_names]
filtered_component_cost_df = component_cost_df.dropna(subset=cost_component_pc_names).sort_values(by='Publication date')

# %%
# Stacked bar chart of cost components, using component_cost_df
fig = px.bar(
    filtered_component_cost_df,
    x='System',
    y=cost_component_pc_names,
    barmode='stack',
)

# axis labels
fig.update_xaxes(title_text='ML model')
fig.update_yaxes(title_text='% of hardware CapEx + OpEx')
fig.update_layout(
    legend=dict(
        title_text='Cost component',
        x=0.60,
        y=0.05,
    )
)
# limits 0 to 100
fig.update_yaxes(range=[0, 100])

fig.update_yaxes(tickvals=list(range(0, 101, 10)))

# size
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
)

# margins
fig.update_layout(margin=dict(l=10, r=10, t=40, b=10))

save_plot(fig, results_dir, 'cost_component_percentage')

fig.show()

# %%
fig = px.bar(
    filtered_component_cost_df,
    x='System',
    y='Energy cost (%)',
    barmode='stack',
    # labels='Cost %',
    # text='Energy cost %',
)
# axis labels
fig.update_xaxes(title_text='System')
fig.update_yaxes(title_text='Energy cost (% of Hardware CapEx + OpEx)')
# fig.update_layout(
#     legend=dict(
#         title_text='Cost component',
#         x=0.75,
#         y=0.05,
#     )
# )
# limits 0 to 100
fig.update_yaxes(range=[0, 30])
# size
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
)

# margins
fig.update_layout(margin=dict(l=10, r=10, t=40, b=10))

save_plot(fig, results_dir, 'energy_percentage')

fig.show()

# %%
fig = px.scatter(
    filtered_component_cost_df,
    x='Publication date',
    y='Energy cost',
    text='System',
)
# axis labels
fig.update_xaxes(title_text='System')
fig.update_yaxes(title_text='Energy cost')
# log y
fig.update_yaxes(type='log')
# size
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
)

# margins
fig.update_layout(margin=dict(l=10, r=10, t=40, b=10))

save_plot(fig, results_dir, 'energy_cost')

fig.show()

# %%
from energy import energy_price

# Stacked bar chart of cost components, using component_cost_df
filtered_component_cost_df.loc[:, 'Energy (kWh)'] = [
    row['Energy cost'] / energy_price(row['Publication date'].year) 
    for _, row in filtered_component_cost_df.iterrows()
]
fig = px.scatter(
    filtered_component_cost_df,
    x='Publication date',
    y='Energy (kWh)',
    text='System',
)
# log y
fig.update_yaxes(type='log')
# size
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
)

# margins
fig.update_layout(margin=dict(l=10, r=10, t=40, b=10))

save_plot(fig, results_dir, 'energy_kwh')

fig.show()

# %%
filtered_component_cost_df = filtered_component_cost_df.dropna(subset=['Training hardware'])
filtered_component_cost_df.loc[:, 'Power capacity for 3-month training run (kW)'] = [
    row['Energy cost'] \
    / energy_price(row['Publication date'].year) \
    / (HOURS_PER_YEAR/4) \
    / server_TDP_fraction(row['Training hardware']) \
    for _, row in filtered_component_cost_df.iterrows()
]

fig = px.scatter(
    filtered_component_cost_df,
    x='Publication date',
    y='Power capacity for 3-month training run (kW)',
    text='System',
)
# log y
fig.update_yaxes(type='log')
# size
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
)

# margins
fig.update_layout(margin=dict(l=10, r=10, t=40, b=10))

save_plot(fig, results_dir, 'power_capacity_kw')

fig.show()

# %%
filtered_component_cost_df['Publication date (float)'] = datetime_to_float_year(
    pd.to_datetime(filtered_component_cost_df['Publication date'])
)

# %%
energy_reg_results = fit_ols_regression(
    filtered_component_cost_df,
    ['Publication date (float)'],
    'Power capacity for 3-month training run (kW)',
    logy=True
)
energy_reg_results.summary()
